# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from collections import Counter
import pickle as pkl
import random
import pdb

# %%
train_data = open('hw2_data/snli_train.tsv').read().split('\n')

# %%
train_data_df = pd.DataFrame.from_csv('hw2_data/snli_train.tsv', sep='\t', index_col=None)
test_data_df = pd.DataFrame.from_csv('hw2_data/snli_val.tsv', sep='\t', index_col=None)
train_data_df
# Out:
#                                                sentence1  \
# 0      A young girl in a pink shirt sitting on a dock...
# 1      A woman is smiling while the man next to her i...
# 2      Across the river , you can see a large building .
# 3      a man in white shorts and a black shirt is par...
# 4      Four black dogs run together on bright green g...
# 5      A female laying on her stomach in the water ou...
# 6       Children eat at a long table with black chairs .
# 7                  A person rides a motorcycle quickly .
# 8      Woman riding a red bicycle down a city street ...
# 9      Two young women dancers , one brunette and one...
# 10     The black dog is jumping over the white pole i...
# 11     Two young adults are setting up the video came...
# 12     A young boy in a Sesame Street bib sits in his...
# 13     A woman with long hair is talking to two men i...
# 14     A group of people eating at an outside cafe wi...
# 15     a man walking the streets while playing the gu...
# 16     There is a girl decorating for an event and a ...
# 17     A biker kneels down with his bike on the pavem...
# 18        One person snowboarding while others look on .
# 19     A man hurls a ball down his lane at a bowling ...
# 20                  A red race car leaves smoke behind .
# 21     Two men are standing behind an eclectic group ...
# 22                    A dog climbing a steep dirt hill .
# 23     A person in a white hat and yellow top enters ...
# 24            People look at lit up buildings at night .
# 25     People sitting down mending fishing nets along...
# 26      A man stands on boards on top of a huge ladder .
# 27                     Two men are riding a motorcycle .
# 28     A girl dressed in a pink sweatshirt and pink a...
# 29         Child in a stroller with an orange shirt on .
# ...                                                  ...
# 99970                       A man making cement risers .
# 99971  A crowd looks on as a band plays music on a st...
# 99972  A woman of east-Asian ancestry holds her right...
# 99973  A balding man in a dark suit and maroon tie , ...
# 99974  this is a group of people participating in a race
# 99975               A blond woman swinging from a pole .
# 99976                     there 's wedding at the church
# 99977                A kid has a pout look on his face .
# 99978  A young girl floats on her back in water and p...
# 99979  Two men in black leather jackets , glasses , a...
# 99980  Across from the Bank of Oklahoma , a woman enj...
# 99981        A man is singing with a clown just behind .
# 99982       People standing in line in a crowded place .
# 99983  A black and white dog is carrying a blue ball ...
# 99984  A man in a dark jacket with white gloves smoke...
# 99985  Two young males watch another male skateboardi...
# 99986  Several women sit holding handrails on an incl...
# 99987                   A man snowboarding down a hill .
# 99988   Two look-alike dogs running in the green grass .
# 99989                  Several people are riding bikes .
# 99990  A rodeo cowboy is trying to stay on a bucking ...
# 99991  A man and a woman on bikes are bicycling down ...
# 99992  A public worker is sweeping up a massive pile ...
# 99993             A man posing for the camera on steps .
# 99994  Older man in full denim welds metal on workben...
# 99995  A crowd of people watching a fellow on a unicy...
# 99996  A little boy sticks his tongue out for the cam...
# 99997          She walks past the beautiful blue mural .
# 99998  Two dogs fighting in a forest , with the legs ...
# 99999  Two gentlemen in tuxes play the keyboard and g...
#
#                                                sentence2          label
# 0      A young girl watching the sunset over the water .        neutral
# 1                    Two people are next to each other .     entailment
# 2      The large building is full of apartments and t...        neutral
# 3                A man is riding a jetski on the ocean .  contradiction
# 4      Four dogs are preparing to be launched into sp...  contradiction
# 5                              There is a women outdoors     entailment
# 6                Kids at a short table with red chairs .  contradiction
# 7           The man is racing his motorcycle in a race .        neutral
# 8                                   person riding a bike     entailment
# 9                         Two women are wearing costumes     entailment
# 10                             The dog is jumping high .        neutral
# 11               The two people are setting up a table .  contradiction
# 12       A young boy in a Sesame Street bib does n't sit  contradiction
# 13     There was a longhaired lady talking with two p...     entailment
# 14                There are people outside of the cafe .     entailment
# 15     A strolling minstrel plays guitar on Bourbon S...        neutral
# 16                    A girl is decorating for a dance .        neutral
# 17               The biker is tired of riding his bike .        neutral
# 18          A woman is snowboarding with no one around .  contradiction
# 19                     A man is inside a bowling alley .     entailment
# 20                         A car sits idly in a garage .  contradiction
# 21                                       the men are old        neutral
# 22                        The dog 's owner is up ahead .        neutral
# 23     A man wearing a hat boards a city bus while an...        neutral
# 24                             The people are tourists .        neutral
# 25                                  People are outside .     entailment
# 26                         The man is painting a house .        neutral
# 27                   A couple people ride a motorcycle .     entailment
# 28                           A girl plays at the beach .     entailment
# 29                      There is a design on the shirt .        neutral
# ...                                                  ...            ...
# 99970                                A man pushes a cart  contradiction
# 99971  The band played an encore performance for the ...        neutral
# 99972  A woman is a teacher in a school having her pi...        neutral
# 99973  young blonde woman in a blue shirt and skirt p...  contradiction
# 99974         A group of people are running a marathon .        neutral
# 99975                    An acrobat swings from a pole .        neutral
# 99976              Famous wedding being held at church .        neutral
# 99977  The kid is annoyed because he did n't get his ...        neutral
# 99978                               The girl ca n't swim        neutral
# 99979                           huge humans with jackets        neutral
# 99980               A warm drink calms the young woman .     entailment
# 99981  A man is sleeping and a clown is in front of h...  contradiction
# 99982   People are waiting in line for concert tickets .        neutral
# 99983               The dog is carrying a big red bone .  contradiction
# 99984                            The man has gloves on .     entailment
# 99985  Two girls watching a guy they like ride his sk...  contradiction
# 99986         The women hold tight in case of accident .        neutral
# 99987                 A woman snowboarding down a hill .  contradiction
# 99988                     Two dogs are running outside .     entailment
# 99989  A lot of people rides their bikes on the shore...        neutral
# 99990                                the child was happy        neutral
# 99991  A man and woman on bicycles ride pass an orang...        neutral
# 99992                              Person sweeping trash     entailment
# 99993        The man is in th eliving room watching TV .  contradiction
# 99994                        Older man watches Youtube .  contradiction
# 99995               A man is riding in front of others .     entailment
# 99996  A boy is playing video games while another boy...  contradiction
# 99997               A woman in blue walks past a mural .        neutral
# 99998                   The two dogs are playing poker .  contradiction
# 99999                       The two guys are in a band .        neutral
#
# [100000 rows x 3 columns]

# %%
train_data_df['token1'] = [x.split() for x in train_data_df.sentence1]
train_data_df['token2'] = [x.split() for x in train_data_df.sentence2]

# %%
test_data_df['token1'] = [x.split() for x in test_data_df.sentence1]
test_data_df['token2'] = [x.split() for x in test_data_df.sentence2]

# %%
words_to_load = 50000
PAD_IDX = 0
UNK_IDX = 1
import numpy as np
# reserve the 1st 2nd token for padding and <UNK> respectively
with open('wiki-news-300d-1M.vec') as f:
    loaded_embeddings_ft = np.zeros((words_to_load+2, 300))
    words_ft = {}
    idx2words_ft = {}
    ordered_words_ft = []
    ordered_words_ft.extend(['<pad>', '<unk>'])
    loaded_embeddings_ft[0,:] = np.zeros(300)
    loaded_embeddings_ft[1,:] = np.random.normal(size = 300)
    for i, line in enumerate(f):
        if i >= words_to_load: 
            break
        s = line.split()
        loaded_embeddings_ft[i+2, :] = np.asarray(s[1:])
        words_ft[s[0]] = i+2
        idx2words_ft[i] = s[0]
        ordered_words_ft.append(s[0])
    words_ft['<pad>'] = 0
    words_ft['<unk>'] = 1

# %%
words_ft
# Out:
# {'999994': 2,
#  ',': 3,
#  'the': 4,
#  '.': 5,
#  'and': 6,
#  'of': 7,
#  'to': 8,
#  'in': 9,
#  'a': 10,
#  '"': 11,
#  ':': 12,
#  ')': 13,
#  'that': 14,
#  '(': 15,
#  'is': 16,
#  'for': 17,
#  'on': 18,
#  '*': 19,
#  'with': 20,
#  'as': 21,
#  'it': 22,
#  'The': 23,
#  'or': 24,
#  'was': 25,
#  "'": 26,
#  "'s": 27,
#  'by': 28,
#  'from': 29,
#  'at': 30,
#  'I': 31,
#  'this': 32,
#  'you': 33,
#  '/': 34,
#  'are': 35,
#  '=': 36,
#  'not': 37,
#  '-': 38,
#  'have': 39,
#  '?': 40,
#  'be': 41,
#  'which': 42,
#  ';': 43,
#  'all': 44,
#  'his': 45,
#  'has': 46,
#  'one': 47,
#  'their': 48,
#  'about': 49,
#  'but': 50,
#  'an': 51,
#  '|': 52,
#  'said': 53,
#  'more': 54,
#  'page': 55,
#  'he': 56,
#  'your': 57,
#  'will': 58,
#  'its': 59,
#  'so': 60,
#  'were': 61,
#  'had': 62,
#  'also': 63,
#  'only': 64,
#  'if': 65,
#  'time': 66,
#  'some': 67,
#  'people': 68,
#  'like': 69,
#  'who': 70,
#  'them': 71,
#  'other': 72,
#  'they': 73,
#  'when': 74,
#  'Wikipedia': 75,
#  'article': 76,
#  'what': 77,
#  '#': 78,
#  'just': 79,
#  '!': 80,
#  'any': 81,
#  'after': 82,
#  'there': 83,
#  'would': 84,
#  'can': 85,
#  'In': 86,
#  'her': 87,
#  'talk': 88,
#  'use': 89,
#  'then': 90,
#  'into': 91,
#  'up': 92,
#  '...': 93,
#  'we': 94,
#  'over': 95,
#  'my': 96,
#  'out': 97,
#  'here': 98,
#  'now': 99,
#  'because': 100,
#  'do': 101,
#  'work': 102,
#  'than': 103,
#  'no': 104,
#  'UTC': 105,
#  'me': 106,
#  'A': 107,
#  'two': 108,
#  'our': 109,
#  'been': 110,
#  'new': 111,
#  'where': 112,
#  '–': 113,
#  'first': 114,
#  'such': 115,
#  'made': 116,
#  '--': 117,
#  'If': 118,
#  "'t": 119,
#  'both': 120,
#  'before': 121,
#  'way': 122,
#  '1': 123,
#  'through': 124,
#  'information': 125,
#  'him': 126,
#  'being': 127,
#  'many': 128,
#  'most': 129,
#  'But': 130,
#  'those': 131,
#  'while': 132,
#  'name': 133,
#  'This': 134,
#  'should': 135,
#  'how': 136,
#  'even': 137,
#  'these': 138,
#  'see': 139,
#  'It': 140,
#  'make': 141,
#  'may': 142,
#  '2': 143,
#  'under': 144,
#  '—': 145,
#  's': 146,
#  'year': 147,
#  '10': 148,
#  'state': 149,
#  'since': 150,
#  'years': 151,
#  '”': 152,
#  'edit': 153,
#  'right': 154,
#  'did': 155,
#  'used': 156,
#  'government': 157,
#  'case': 158,
#  'articles': 159,
#  'get': 160,
#  'between': 161,
#  'she': 162,
#  '“': 163,
#  '}': 164,
#  'think': 165,
#  '20': 166,
#  'during': 167,
#  'another': 168,
#  'And': 169,
#  '11': 170,
#  '3': 171,
#  'could': 172,
#  'using': 173,
#  'He': 174,
#  'without': 175,
#  'good': 176,
#  'place': 177,
#  'support': 178,
#  'back': 179,
#  'again': 180,
#  'against': 181,
#  '12': 182,
#  '15': 183,
#  'system': 184,
#  'called': 185,
#  'much': 186,
#  'still': 187,
#  '18': 188,
#  '%': 189,
#  '16': 190,
#  'change': 191,
#  'say': 192,
#  'point': 193,
#  'us': 194,
#  'group': 195,
#  'day': 196,
#  'three': 197,
#  '17': 198,
#  '14': 199,
#  'know': 200,
#  'help': 201,
#  'As': 202,
#  'last': 203,
#  '21': 204,
#  'each': 205,
#  'around': 206,
#  '2008': 207,
#  'edits': 208,
#  'says': 209,
#  '’': 210,
#  '13': 211,
#  '19': 212,
#  'life': 213,
#  'link': 214,
#  '22': 215,
#  'too': 216,
#  'left': 217,
#  '2009': 218,
#  'very': 219,
#  'students': 220,
#  'team': 221,
#  'sources': 222,
#  'off': 223,
#  '2007': 224,
#  'well': 225,
#  '4': 226,
#  'down': 227,
#  'section': 228,
#  'take': 229,
#  'does': 230,
#  'really': 231,
#  '23': 232,
#  'discussion': 233,
#  'either': 234,
#  'show': 235,
#  'public': 236,
#  '2010': 237,
#  'including': 238,
#  'set': 239,
#  'game': 240,
#  'policy': 241,
#  'later': 242,
#  'need': 243,
#  'program': 244,
#  'others': 245,
#  'source': 246,
#  'research': 247,
#  '+': 248,
#  'area': 249,
#  'children': 250,
#  'why': 251,
#  'family': 252,
#  'making': 253,
#  'deletion': 254,
#  'something': 255,
#  'content': 256,
#  'school': 257,
#  'added': 258,
#  'found': 259,
#  'until': 260,
#  'within': 261,
#  'following': 262,
#  'better': 263,
#  '5': 264,
#  'process': 265,
#  '&': 266,
#  'history': 267,
#  'You': 268,
#  'given': 269,
#  '2011': 270,
#  'question': 271,
#  'women': 272,
#  'For': 273,
#  'country': 274,
#  'company': 275,
#  'data': 276,
#  'part': 277,
#  'include': 278,
#  'site': 279,
#  'pages': 280,
#  'home': 281,
#  'business': 282,
#  '$': 283,
#  '2006': 284,
#  'having': 285,
#  'American': 286,
#  '2012': 287,
#  'put': 288,
#  'issue': 289,
#  'different': 290,
#  'world': 291,
#  'U.S.': 292,
#  'New': 293,
#  'things': 294,
#  'list': 295,
#  'power': 296,
#  'above': 297,
#  'best': 298,
#  'future': 299,
#  'read': 300,
#  'report': 301,
#  'project': 302,
#  'find': 303,
#  'problem': 304,
#  'book': 305,
#  'though': 306,
#  'law': 307,
#  'today': 308,
#  'We': 309,
#  'four': 310,
#  'links': 311,
#  'community': 312,
#  'several': 313,
#  'film': 314,
#  'So': 315,
#  '30': 316,
#  'free': 317,
#  'money': 318,
#  'line': 319,
#  'service': 320,
#  'actually': 321,
#  '2013': 322,
#  'second': 323,
#  'go': 324,
#  'deleted': 325,
#  'editing': 326,
#  'often': 327,
#  'every': 328,
#  '00': 329,
#  'course': 330,
#  'season': 331,
#  'possible': 332,
#  'That': 333,
#  'US': 334,
#  'war': 335,
#  'title': 336,
#  'local': 337,
#  'once': 338,
#  'study': 339,
#  'whether': 340,
#  'University': 341,
#  'yet': 342,
#  '6': 343,
#  '2014': 344,
#  'already': 345,
#  'issues': 346,
#  'got': 347,
#  'man': 348,
#  'Please': 349,
#  'services': 350,
#  'look': 351,
#  'questions': 352,
#  'On': 353,
#  'When': 354,
#  'removed': 355,
#  'men': 356,
#  'They': 357,
#  'form': 358,
#  'water': 359,
#  'view': 360,
#  'English': 361,
#  '25': 362,
#  'review': 363,
#  'person': 364,
#  'important': 365,
#  'changes': 366,
#  'further': 367,
#  'What': 368,
#  'own': 369,
#  'States': 370,
#  'present': 371,
#  'welcome': 372,
#  'might': 373,
#  'development': 374,
#  'done': 375,
#  'must': 376,
#  'someone': 377,
#  'told': 378,
#  'early': 379,
#  'British': 380,
#  'material': 381,
#  'position': 382,
#  'means': 383,
#  'created': 384,
#  'please': 385,
#  'thing': 386,
#  'text': 387,
#  'high': 388,
#  'itself': 389,
#  'long': 390,
#  'number': 391,
#  'started': 392,
#  '2015': 393,
#  'won': 394,
#  '24': 395,
#  'great': 396,
#  'start': 397,
#  'experience': 398,
#  'China': 399,
#  'party': 400,
#  'May': 401,
#  'current': 402,
#  'building': 403,
#  'play': 404,
#  '7': 405,
#  'always': 406,
#  'anything': 407,
#  'want': 408,
#  'fact': 409,
#  'series': 410,
#  'old': 411,
#  'included': 412,
#  'provide': 413,
#  'among': 414,
#  '2005': 415,
#  'story': 416,
#  'police': 417,
#  'There': 418,
#  'media': 419,
#  'days': 420,
#  'never': 421,
#  'probably': 422,
#  'No': 423,
#  'add': 424,
#  'next': 425,
#  'death': 426,
#  'took': 427,
#  'market': 428,
#  'city': 429,
#  'field': 430,
#  'music': 431,
#  'same': 432,
#  'working': 433,
#  'language': 434,
#  'problems': 435,
#  'needs': 436,
#  'reverted': 437,
#  'England': 438,
#  'less': 439,
#  'control': 440,
#  'London': 441,
#  'run': 442,
#  'image': 443,
#  'record': 444,
#  'believe': 445,
#  'former': 446,
#  'comment': 447,
#  'general': 448,
#  'don': 449,
#  'end': 450,
#  'After': 451,
#  'All': 452,
#  'education': 453,
#  'recent': 454,
#  'little': 455,
#  'political': 456,
#  'known': 457,
#  'open': 458,
#  'move': 459,
#  'evidence': 460,
#  'thought': 461,
#  'test': 462,
#  'message': 463,
#  '8': 464,
#  'rather': 465,
#  'members': 466,
#  'simply': 467,
#  'John': 468,
#  'week': 469,
#  'State': 470,
#  'real': 471,
#  'small': 472,
#  'user': 473,
#  'available': 474,
#  'reason': 475,
#  'staff': 476,
#  'account': 477,
#  'clear': 478,
#  'Image': 479,
#  'saying': 480,
#  'plan': 481,
#  'words': 482,
#  'works': 483,
#  'changed': 484,
#  'doing': 485,
#  'lead': 486,
#  'million': 487,
#  'house': 488,
#  'give': 489,
#  'term': 490,
#  'full': 491,
#  '2016': 492,
#  'keep': 493,
#  'website': 494,
#  'top': 495,
#  'March': 496,
#  'enough': 497,
#  'themselves': 498,
#  'action': 499,
#  '~': 500,
#  ']': 501,
#  'come': 502,
#  'provided': 503,
#  'five': 504,
#  'near': 505,
#  'job': 506,
#  'feel': 507,
#  'points': 508,
#  'One': 509,
#  'ever': 510,
#  'leave': 511,
#  'results': 512,
#  'technology': 513,
#  'At': 514,
#  'date': 515,
#  '29': 516,
#  'Thank': 517,
#  'With': 518,
#  'subject': 519,
#  '9': 520,
#  '26': 521,
#  '27': 522,
#  'became': 523,
#  'times': 524,
#  '28': 525,
#  'vote': 526,
#  'countries': 527,
#  'going': 528,
#  'seen': 529,
#  'outside': 530,
#  'taking': 531,
#  'level': 532,
#  'word': 533,
#  'national': 534,
#  'event': 535,
#  'WP': 536,
#  'health': 537,
#  'call': 538,
#  'along': 539,
#  'class': 540,
#  'America': 541,
#  'January': 542,
#  'large': 543,
#  'programs': 544,
#  'Talk': 545,
#  'April': 546,
#  'major': 547,
#  'UK': 548,
#  'court': 549,
#  'together': 550,
#  'vandalism': 551,
#  'period': 552,
#  'getting': 553,
#  'example': 554,
#  '[': 555,
#  'claim': 556,
#  'French': 557,
#  'Australia': 558,
#  'himself': 559,
#  'areas': 560,
#  'design': 561,
#  'writing': 562,
#  'interest': 563,
#  'body': 564,
#  'reported': 565,
#  'June': 566,
#  'population': 567,
#  'states': 568,
#  'companies': 569,
#  'wrong': 570,
#  't': 571,
#  'perhaps': 572,
#  'order': 573,
#  'came': 574,
#  'industry': 575,
#  'September': 576,
#  'July': 577,
#  'Russia': 578,
#  'land': 579,
#  'office': 580,
#  'City': 581,
#  'true': 582,
#  'face': 583,
#  'address': 584,
#  'sure': 585,
#  '01': 586,
#  'everyone': 587,
#  'began': 588,
#  'president': 589,
#  'training': 590,
#  'side': 591,
#  'lost': 592,
#  'groups': 593,
#  '2004': 594,
#  'care': 595,
#  'space': 596,
#  'model': 597,
#  'per': 598,
#  'August': 599,
#  'October': 600,
#  'California': 601,
#  'France': 602,
#  'region': 603,
#  'While': 604,
#  'School': 605,
#  'request': 606,
#  'military': 607,
#  'nothing': 608,
#  'food': 609,
#  'events': 610,
#  'House': 611,
#  'individual': 612,
#  'ask': 613,
#  'decision': 614,
#  'policies': 615,
#  '02': 616,
#  'November': 617,
#  'books': 618,
#  'received': 619,
#  'album': 620,
#  'makes': 621,
#  'matter': 622,
#  'based': 623,
#  'December': 624,
#  'contributions': 625,
#  '..': 626,
#  'de': 627,
#  'mean': 628,
#  'news': 629,
#  'written': 630,
#  'images': 631,
#  '31': 632,
#  'systems': 633,
#  'various': 634,
#  'few': 635,
#  'held': 636,
#  'below': 637,
#  'tag': 638,
#  'played': 639,
#  'common': 640,
#  'Europe': 641,
#  '03': 642,
#  'performance': 643,
#  'She': 644,
#  'regarding': 645,
#  'production': 646,
#  'shows': 647,
#  'God': 648,
#  'India': 649,
#  'meeting': 650,
#  'away': 651,
#  'comments': 652,
#  'love': 653,
#  'stop': 654,
#  'practice': 655,
#  'reference': 656,
#  'rules': 657,
#  'head': 658,
#  'editors': 659,
#  'users': 660,
#  'anyone': 661,
#  'let': 662,
#  'statement': 663,
#  'Thanks': 664,
#  'schools': 665,
#  'appropriate': 666,
#  'instead': 667,
#  'campaign': 668,
#  '04': 669,
#  'almost': 670,
#  'Hello': 671,
#  'February': 672,
#  'i': 673,
#  'specific': 674,
#  '0': 675,
#  'players': 676,
#  'To': 677,
#  'hit': 678,
#  'Obama': 679,
#  'User': 680,
#  'President': 681,
#  'World': 682,
#  'names': 683,
#  'past': 684,
#  '05': 685,
#  'night': 686,
#  'least': 687,
#  'age': 688,
#  'note': 689,
#  'social': 690,
#  'management': 691,
#  'considered': 692,
#  'standard': 693,
#  'months': 694,
#  'idea': 695,
#  'deal': 696,
#  'attack': 697,
#  'student': 698,
#  'check': 699,
#  'post': 700,
#  'Now': 701,
#  'behind': 702,
#  'adding': 703,
#  'science': 704,
#  'South': 705,
#  'alt': 706,
#  'references': 707,
#  '....': 708,
#  'Mr.': 709,
#  'security': 710,
#  'Some': 711,
#  'games': 712,
#  'situation': 713,
#  'third': 714,
#  'race': 715,
#  'cases': 716,
#  'guidelines': 717,
#  'force': 718,
#  'German': 719,
#  'human': 720,
#  'light': 721,
#  "'m": 722,
#  'version': 723,
#  'organization': 724,
#  'named': 725,
#  'Germany': 726,
#  'official': 727,
#  'international': 728,
#  'release': 729,
#  'role': 730,
#  'block': 731,
#  'published': 732,
#  'character': 733,
#  'correct': 734,
#  'rule': 735,
#  'song': 736,
#  'six': 737,
#  'visit': 738,
#  'Mr': 739,
#  'value': 740,
#  'video': 741,
#  'usually': 742,
#  'big': 743,
#  'taken': 744,
#  'hope': 745,
#  'claims': 746,
#  'sometimes': 747,
#  'needed': 748,
#  'activities': 749,
#  'Washington': 750,
#  '@': 751,
#  'everything': 752,
#  'club': 753,
#  'remove': 754,
#  'town': 755,
#  'certain': 756,
#  'similar': 757,
#  'uses': 758,
#  'close': 759,
#  'player': 760,
#  "'re": 761,
#  'rights': 762,
#  'North': 763,
#  'Canada': 764,
#  'single': 765,
#  'paper': 766,
#  'potential': 767,
#  'economy': 768,
#  'appear': 769,
#  'society': 770,
#  'proposed': 771,
#  'West': 772,
#  'resources': 773,
#  'search': 774,
#  'cause': 775,
#  'win': 776,
#  'National': 777,
#  'election': 778,
#  'hand': 779,
#  'editor': 780,
#  'seems': 781,
#  'ago': 782,
#  'consensus': 783,
#  'am': 784,
#  'entry': 785,
#  'result': 786,
#  '\\': 787,
#  'far': 788,
#  'style': 789,
#  'wrote': 790,
#  'personal': 791,
#  'effect': 792,
#  'live': 793,
#  '2003': 794,
#  'online': 795,
#  'Israel': 796,
#  'includes': 797,
#  'become': 798,
#  'growth': 799,
#  'Japan': 800,
#  'share': 801,
#  'complete': 802,
#  'young': 803,
#  'earlier': 804,
#  'across': 805,
#  '06': 806,
#  'Hi': 807,
#  'products': 808,
#  'United': 809,
#  'released': 810,
#  'His': 811,
#  'playing': 812,
#  'car': 813,
#  'notable': 814,
#  'Congress': 815,
#  'Although': 816,
#  'offer': 817,
#  'child': 818,
#  'bad': 819,
#  'network': 820,
#  'notice': 821,
#  'energy': 822,
#  'knowledge': 823,
#  'European': 824,
#  'sandbox': 825,
#  '07': 826,
#  'asked': 827,
#  '09': 828,
#  'sites': 829,
#  'pay': 830,
#  '08': 831,
#  'understand': 832,
#  'reports': 833,
#  'product': 834,
#  'poor': 835,
#  'return': 836,
#  'short': 837,
#  'running': 838,
#  'constructive': 839,
#  'reading': 840,
#  'half': 841,
#  'currently': 842,
#  '2000': 843,
#  'required': 844,
#  'culture': 845,
#  'software': 846,
#  'nor': 847,
#  'projects': 848,
#  'Scotland': 849,
#  'match': 850,
#  'cost': 851,
#  'upon': 852,
#  'benefits': 853,
#  'First': 854,
#  'success': 855,
#  'My': 856,
#  'established': 857,
#  'David': 858,
#  'parents': 859,
#  'private': 860,
#  'property': 861,
#  'quality': 862,
#  'key': 863,
#  'whose': 864,
#  'sense': 865,
#  'theory': 866,
#  'numbers': 867,
#  'clearly': 868,
#  'Chinese': 869,
#  'continue': 870,
#  'treatment': 871,
#  'access': 872,
#  'living': 873,
#  'late': 874,
#  'total': 875,
#  'file': 876,
#  'band': 877,
#  'month': 878,
#  'species': 879,
#  'consider': 880,
#  'By': 881,
#  'original': 882,
#  'answer': 883,
#  'From': 884,
#  'black': 885,
#  'conditions': 886,
#  'air': 887,
#  'involved': 888,
#  'century': 889,
#  'leading': 890,
#  'fire': 891,
#  '50': 892,
#  'art': 893,
#  '•': 894,
#  'opinion': 895,
#  'final': 896,
#  'yourself': 897,
#  'gave': 898,
#  'environment': 899,
#  'saw': 900,
#  'debate': 901,
#  'costs': 902,
#  'developed': 903,
#  '100': 904,
#  'economic': 905,
#  'try': 906,
#  'Britain': 907,
#  'therefore': 908,
#  'category': 909,
#  'white': 910,
#  'friends': 911,
#  'type': 912,
#  'cut': 913,
#  'station': 914,
#  'church': 915,
#  'template': 916,
#  'Not': 917,
#  'myself': 918,
#  'risk': 919,
#  'mind': 920,
#  'via': 921,
#  'Texas': 922,
#  'hours': 923,
#  'War': 924,
#  'generally': 925,
#  'particular': 926,
#  'alone': 927,
#  'likely': 928,
#  '2001': 929,
#  'board': 930,
#  'structure': 931,
#  'significant': 932,
#  'tax': 933,
#  'approach': 934,
#  'hard': 935,
#  'movement': 936,
#  'provides': 937,
#  'legal': 938,
#  'went': 939,
#  'inside': 940,
#  'sentence': 941,
#  'workers': 942,
#  'related': 943,
#  'analysis': 944,
#  'simple': 945,
#  'terms': 946,
#  'ones': 947,
#  'especially': 948,
#  'College': 949,
#  'remains': 950,
#  'topic': 951,
#  'directly': 952,
#  'rate': 953,
#  'turn': 954,
#  'career': 955,
#  'sign': 956,
#  'necessary': 957,
#  'quite': 958,
#  'meaning': 959,
#  'application': 960,
#  'recently': 961,
#  'families': 962,
#  'status': 963,
#  'strong': 964,
#  '2002': 965,
#  'percent': 966,
#  'Russian': 967,
#  'Iraq': 968,
#  'individuals': 969,
#  'capital': 970,
#  'studies': 971,
#  'described': 972,
#  'reliable': 973,
#  'due': 974,
#  'killed': 975,
#  'encyclopedia': 976,
#  'Your': 977,
#  'blocked': 978,
#  'room': 979,
#  'How': 980,
#  'low': 981,
#  'built': 982,
#  'cover': 983,
#  'giving': 984,
#  'worked': 985,
#  'However': 986,
#  'brought': 987,
#  'https': 988,
#  'contact': 989,
#  'speedy': 990,
#  'special': 991,
#  'features': 992,
#  'size': 993,
#  'warning': 994,
#  'woman': 995,
#  'appears': 996,
#  'create': 997,
#  'lives': 998,
#  'standards': 999,
#  'author': 1000,
#  'relevant': 1001,
#  ...}

# %%
loaded_embeddings_ft
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [ -1.25525490e+00,  -1.06705833e+00,   1.37764632e+00, ...,
#           3.30495049e-01,   7.41800195e-01,   1.19833225e+00],
#        [  3.00000000e+02,   3.00000000e+02,   3.00000000e+02, ...,
#           3.00000000e+02,   3.00000000e+02,   3.00000000e+02],
#        ...,
#        [ -1.88900000e-01,  -1.19400000e-01,  -1.56700000e-01, ...,
#          -1.83300000e-01,  -2.76000000e-02,  -2.48500000e-01],
#        [ -9.17000000e-02,  -1.52800000e-01,  -7.59000000e-02, ...,
#          -3.60000000e-03,   2.48000000e-02,   3.47000000e-02],
#        [ -1.86000000e-01,  -7.20000000e-02,  -2.73000000e-02, ...,
#          -1.55800000e-01,  -7.49000000e-02,   2.58400000e-01]])

# %%
ordered_words_ft
# Out:
# ['<pad>',
#  '<unk>',
#  '999994',
#  ',',
#  'the',
#  '.',
#  'and',
#  'of',
#  'to',
#  'in',
#  'a',
#  '"',
#  ':',
#  ')',
#  'that',
#  '(',
#  'is',
#  'for',
#  'on',
#  '*',
#  'with',
#  'as',
#  'it',
#  'The',
#  'or',
#  'was',
#  "'",
#  "'s",
#  'by',
#  'from',
#  'at',
#  'I',
#  'this',
#  'you',
#  '/',
#  'are',
#  '=',
#  'not',
#  '-',
#  'have',
#  '?',
#  'be',
#  'which',
#  ';',
#  'all',
#  'his',
#  'has',
#  'one',
#  'their',
#  'about',
#  'but',
#  'an',
#  '|',
#  'said',
#  'more',
#  'page',
#  'he',
#  'your',
#  'will',
#  'its',
#  'so',
#  'were',
#  'had',
#  'also',
#  'only',
#  'if',
#  'time',
#  'some',
#  'people',
#  'like',
#  'who',
#  'them',
#  'other',
#  'they',
#  'when',
#  'Wikipedia',
#  'article',
#  'what',
#  '#',
#  'just',
#  '!',
#  'any',
#  'after',
#  'there',
#  'would',
#  'can',
#  'In',
#  'her',
#  'talk',
#  'use',
#  'then',
#  'into',
#  'up',
#  '...',
#  'we',
#  'over',
#  'my',
#  'out',
#  'here',
#  'now',
#  'because',
#  'do',
#  'work',
#  'than',
#  'no',
#  'UTC',
#  'me',
#  'A',
#  'two',
#  'our',
#  'been',
#  'new',
#  'where',
#  '–',
#  'first',
#  'such',
#  'made',
#  '--',
#  'If',
#  "'t",
#  'both',
#  'before',
#  'way',
#  '1',
#  'through',
#  'information',
#  'him',
#  'being',
#  'many',
#  'most',
#  'But',
#  'those',
#  'while',
#  'name',
#  'This',
#  'should',
#  'how',
#  'even',
#  'these',
#  'see',
#  'It',
#  'make',
#  'may',
#  '2',
#  'under',
#  '—',
#  's',
#  'year',
#  '10',
#  'state',
#  'since',
#  'years',
#  '”',
#  'edit',
#  'right',
#  'did',
#  'used',
#  'government',
#  'case',
#  'articles',
#  'get',
#  'between',
#  'she',
#  '“',
#  '}',
#  'think',
#  '20',
#  'during',
#  'another',
#  'And',
#  '11',
#  '3',
#  'could',
#  'using',
#  'He',
#  'without',
#  'good',
#  'place',
#  'support',
#  'back',
#  'again',
#  'against',
#  '12',
#  '15',
#  'system',
#  'called',
#  'much',
#  'still',
#  '18',
#  '%',
#  '16',
#  'change',
#  'say',
#  'point',
#  'us',
#  'group',
#  'day',
#  'three',
#  '17',
#  '14',
#  'know',
#  'help',
#  'As',
#  'last',
#  '21',
#  'each',
#  'around',
#  '2008',
#  'edits',
#  'says',
#  '’',
#  '13',
#  '19',
#  'life',
#  'link',
#  '22',
#  'too',
#  'left',
#  '2009',
#  'very',
#  'students',
#  'team',
#  'sources',
#  'off',
#  '2007',
#  'well',
#  '4',
#  'down',
#  'section',
#  'take',
#  'does',
#  'really',
#  '23',
#  'discussion',
#  'either',
#  'show',
#  'public',
#  '2010',
#  'including',
#  'set',
#  'game',
#  'policy',
#  'later',
#  'need',
#  'program',
#  'others',
#  'source',
#  'research',
#  '+',
#  'area',
#  'children',
#  'why',
#  'family',
#  'making',
#  'deletion',
#  'something',
#  'content',
#  'school',
#  'added',
#  'found',
#  'until',
#  'within',
#  'following',
#  'better',
#  '5',
#  'process',
#  '&',
#  'history',
#  'You',
#  'given',
#  '2011',
#  'question',
#  'women',
#  'For',
#  'country',
#  'company',
#  'data',
#  'part',
#  'include',
#  'site',
#  'pages',
#  'home',
#  'business',
#  '$',
#  '2006',
#  'having',
#  'American',
#  '2012',
#  'put',
#  'issue',
#  'different',
#  'world',
#  'U.S.',
#  'New',
#  'things',
#  'list',
#  'power',
#  'above',
#  'best',
#  'future',
#  'read',
#  'report',
#  'project',
#  'find',
#  'problem',
#  'book',
#  'though',
#  'law',
#  'today',
#  'We',
#  'four',
#  'links',
#  'community',
#  'several',
#  'film',
#  'So',
#  '30',
#  'free',
#  'money',
#  'line',
#  'service',
#  'actually',
#  '2013',
#  'second',
#  'go',
#  'deleted',
#  'editing',
#  'often',
#  'every',
#  '00',
#  'course',
#  'season',
#  'possible',
#  'That',
#  'US',
#  'war',
#  'title',
#  'local',
#  'once',
#  'study',
#  'whether',
#  'University',
#  'yet',
#  '6',
#  '2014',
#  'already',
#  'issues',
#  'got',
#  'man',
#  'Please',
#  'services',
#  'look',
#  'questions',
#  'On',
#  'When',
#  'removed',
#  'men',
#  'They',
#  'form',
#  'water',
#  'view',
#  'English',
#  '25',
#  'review',
#  'person',
#  'important',
#  'changes',
#  'further',
#  'What',
#  'own',
#  'States',
#  'present',
#  'welcome',
#  'might',
#  'development',
#  'done',
#  'must',
#  'someone',
#  'told',
#  'early',
#  'British',
#  'material',
#  'position',
#  'means',
#  'created',
#  'please',
#  'thing',
#  'text',
#  'high',
#  'itself',
#  'long',
#  'number',
#  'started',
#  '2015',
#  'won',
#  '24',
#  'great',
#  'start',
#  'experience',
#  'China',
#  'party',
#  'May',
#  'current',
#  'building',
#  'play',
#  '7',
#  'always',
#  'anything',
#  'want',
#  'fact',
#  'series',
#  'old',
#  'included',
#  'provide',
#  'among',
#  '2005',
#  'story',
#  'police',
#  'There',
#  'media',
#  'days',
#  'never',
#  'probably',
#  'No',
#  'add',
#  'next',
#  'death',
#  'took',
#  'market',
#  'city',
#  'field',
#  'music',
#  'same',
#  'working',
#  'language',
#  'problems',
#  'needs',
#  'reverted',
#  'England',
#  'less',
#  'control',
#  'London',
#  'run',
#  'image',
#  'record',
#  'believe',
#  'former',
#  'comment',
#  'general',
#  'don',
#  'end',
#  'After',
#  'All',
#  'education',
#  'recent',
#  'little',
#  'political',
#  'known',
#  'open',
#  'move',
#  'evidence',
#  'thought',
#  'test',
#  'message',
#  '8',
#  'rather',
#  'members',
#  'simply',
#  'John',
#  'week',
#  'State',
#  'real',
#  'small',
#  'user',
#  'available',
#  'reason',
#  'staff',
#  'account',
#  'clear',
#  'Image',
#  'saying',
#  'plan',
#  'words',
#  'works',
#  'changed',
#  'doing',
#  'lead',
#  'million',
#  'house',
#  'give',
#  'term',
#  'full',
#  '2016',
#  'keep',
#  'website',
#  'top',
#  'March',
#  'enough',
#  'themselves',
#  'action',
#  '~',
#  ']',
#  'come',
#  'provided',
#  'five',
#  'near',
#  'job',
#  'feel',
#  'points',
#  'One',
#  'ever',
#  'leave',
#  'results',
#  'technology',
#  'At',
#  'date',
#  '29',
#  'Thank',
#  'With',
#  'subject',
#  '9',
#  '26',
#  '27',
#  'became',
#  'times',
#  '28',
#  'vote',
#  'countries',
#  'going',
#  'seen',
#  'outside',
#  'taking',
#  'level',
#  'word',
#  'national',
#  'event',
#  'WP',
#  'health',
#  'call',
#  'along',
#  'class',
#  'America',
#  'January',
#  'large',
#  'programs',
#  'Talk',
#  'April',
#  'major',
#  'UK',
#  'court',
#  'together',
#  'vandalism',
#  'period',
#  'getting',
#  'example',
#  '[',
#  'claim',
#  'French',
#  'Australia',
#  'himself',
#  'areas',
#  'design',
#  'writing',
#  'interest',
#  'body',
#  'reported',
#  'June',
#  'population',
#  'states',
#  'companies',
#  'wrong',
#  't',
#  'perhaps',
#  'order',
#  'came',
#  'industry',
#  'September',
#  'July',
#  'Russia',
#  'land',
#  'office',
#  'City',
#  'true',
#  'face',
#  'address',
#  'sure',
#  '01',
#  'everyone',
#  'began',
#  'president',
#  'training',
#  'side',
#  'lost',
#  'groups',
#  '2004',
#  'care',
#  'space',
#  'model',
#  'per',
#  'August',
#  'October',
#  'California',
#  'France',
#  'region',
#  'While',
#  'School',
#  'request',
#  'military',
#  'nothing',
#  'food',
#  'events',
#  'House',
#  'individual',
#  'ask',
#  'decision',
#  'policies',
#  '02',
#  'November',
#  'books',
#  'received',
#  'album',
#  'makes',
#  'matter',
#  'based',
#  'December',
#  'contributions',
#  '..',
#  'de',
#  'mean',
#  'news',
#  'written',
#  'images',
#  '31',
#  'systems',
#  'various',
#  'few',
#  'held',
#  'below',
#  'tag',
#  'played',
#  'common',
#  'Europe',
#  '03',
#  'performance',
#  'She',
#  'regarding',
#  'production',
#  'shows',
#  'God',
#  'India',
#  'meeting',
#  'away',
#  'comments',
#  'love',
#  'stop',
#  'practice',
#  'reference',
#  'rules',
#  'head',
#  'editors',
#  'users',
#  'anyone',
#  'let',
#  'statement',
#  'Thanks',
#  'schools',
#  'appropriate',
#  'instead',
#  'campaign',
#  '04',
#  'almost',
#  'Hello',
#  'February',
#  'i',
#  'specific',
#  '0',
#  'players',
#  'To',
#  'hit',
#  'Obama',
#  'User',
#  'President',
#  'World',
#  'names',
#  'past',
#  '05',
#  'night',
#  'least',
#  'age',
#  'note',
#  'social',
#  'management',
#  'considered',
#  'standard',
#  'months',
#  'idea',
#  'deal',
#  'attack',
#  'student',
#  'check',
#  'post',
#  'Now',
#  'behind',
#  'adding',
#  'science',
#  'South',
#  'alt',
#  'references',
#  '....',
#  'Mr.',
#  'security',
#  'Some',
#  'games',
#  'situation',
#  'third',
#  'race',
#  'cases',
#  'guidelines',
#  'force',
#  'German',
#  'human',
#  'light',
#  "'m",
#  'version',
#  'organization',
#  'named',
#  'Germany',
#  'official',
#  'international',
#  'release',
#  'role',
#  'block',
#  'published',
#  'character',
#  'correct',
#  'rule',
#  'song',
#  'six',
#  'visit',
#  'Mr',
#  'value',
#  'video',
#  'usually',
#  'big',
#  'taken',
#  'hope',
#  'claims',
#  'sometimes',
#  'needed',
#  'activities',
#  'Washington',
#  '@',
#  'everything',
#  'club',
#  'remove',
#  'town',
#  'certain',
#  'similar',
#  'uses',
#  'close',
#  'player',
#  "'re",
#  'rights',
#  'North',
#  'Canada',
#  'single',
#  'paper',
#  'potential',
#  'economy',
#  'appear',
#  'society',
#  'proposed',
#  'West',
#  'resources',
#  'search',
#  'cause',
#  'win',
#  'National',
#  'election',
#  'hand',
#  'editor',
#  'seems',
#  'ago',
#  'consensus',
#  'am',
#  'entry',
#  'result',
#  '\\',
#  'far',
#  'style',
#  'wrote',
#  'personal',
#  'effect',
#  'live',
#  '2003',
#  'online',
#  'Israel',
#  'includes',
#  'become',
#  'growth',
#  'Japan',
#  'share',
#  'complete',
#  'young',
#  'earlier',
#  'across',
#  '06',
#  'Hi',
#  'products',
#  'United',
#  'released',
#  'His',
#  'playing',
#  'car',
#  'notable',
#  'Congress',
#  'Although',
#  'offer',
#  'child',
#  'bad',
#  'network',
#  'notice',
#  'energy',
#  'knowledge',
#  'European',
#  'sandbox',
#  '07',
#  'asked',
#  '09',
#  'sites',
#  'pay',
#  '08',
#  'understand',
#  'reports',
#  'product',
#  'poor',
#  'return',
#  'short',
#  'running',
#  'constructive',
#  'reading',
#  'half',
#  'currently',
#  '2000',
#  'required',
#  'culture',
#  'software',
#  'nor',
#  'projects',
#  'Scotland',
#  'match',
#  'cost',
#  'upon',
#  'benefits',
#  'First',
#  'success',
#  'My',
#  'established',
#  'David',
#  'parents',
#  'private',
#  'property',
#  'quality',
#  'key',
#  'whose',
#  'sense',
#  'theory',
#  'numbers',
#  'clearly',
#  'Chinese',
#  'continue',
#  'treatment',
#  'access',
#  'living',
#  'late',
#  'total',
#  'file',
#  'band',
#  'month',
#  'species',
#  'consider',
#  'By',
#  'original',
#  'answer',
#  'From',
#  'black',
#  'conditions',
#  'air',
#  'involved',
#  'century',
#  'leading',
#  'fire',
#  '50',
#  'art',
#  '•',
#  'opinion',
#  'final',
#  'yourself',
#  'gave',
#  'environment',
#  'saw',
#  'debate',
#  'costs',
#  'developed',
#  '100',
#  'economic',
#  'try',
#  'Britain',
#  'therefore',
#  'category',
#  'white',
#  'friends',
#  'type',
#  'cut',
#  'station',
#  'church',
#  'template',
#  'Not',
#  'myself',
#  'risk',
#  'mind',
#  'via',
#  'Texas',
#  'hours',
#  'War',
#  'generally',
#  'particular',
#  'alone',
#  'likely',
#  '2001',
#  'board',
#  'structure',
#  'significant',
#  'tax',
#  'approach',
#  'hard',
#  'movement',
#  'provides',
#  'legal',
#  'went',
#  'inside',
#  'sentence',
#  'workers',
#  'related',
#  'analysis',
#  'simple',
#  'terms',
#  'ones',
#  'especially',
#  'College',
#  'remains',
#  'topic',
#  'directly',
#  'rate',
#  'turn',
#  'career',
#  'sign',
#  'necessary',
#  'quite',
#  'meaning',
#  'application',
#  'recently',
#  'families',
#  'status',
#  'strong',
#  '2002',
#  'percent',
#  'Russian',
#  'Iraq',
#  'individuals',
#  'capital',
#  'studies',
#  'described',
#  'reliable',
#  'due',
#  'killed',
#  'encyclopedia',
#  'Your',
#  'blocked',
#  'room',
#  'How',
#  'low',
#  'built',
#  'cover',
#  'giving',
#  'worked',
#  'However',
#  'brought',
#  'https',
#  'contact',
#  'speedy',
#  'special',
#  'features',
#  'size',
#  'warning',
#  'woman',
#  'appears',
#  'create',
#  'lives',
#  'standards',
#  ...]

# %%
# convert tokens in df to word vectors 
label_dic = {'neutral':0, 'contradiction':1, 'entailment':2}
def word_to_vec(word_list):
    return [loaded_embeddings_ft[words_ft[x]] if x in ordered_words_ft else loaded_embeddings_ft[1] for x in word_list]
def word_to_id(word_list):
    return [words_ft[x] if x in ordered_words_ft else UNK_IDX for x in word_list]
def convert_data(df):
    df['token1_x'] = df['token1'].apply(lambda x: word_to_vec(x))
    df['token2_x'] = df['token2'].apply(lambda x: word_to_vec(x))
    df['y'] = df['label'].apply(lambda x: label_dic[x])
    return df

# %%
train_data_df2 = convert_data(train_data_df)
test_data_df2 = convert_data(test_data_df)

# %%
train_list_pre = train_data_df['token1'].values.tolist()
train_list_hypo = train_data_df['token2'].values.tolist()
test_list_pre = test_data_df['token1'].values.tolist()
test_list_hypo = test_data_df['token2'].values.tolist()

# %%
def list2id(sent_list):
    return [word_to_id(x) for x in sent_list]

# %%
train_id_pre = list2id(train_list_pre)
train_id_hypo = list2id(train_list_hypo)
test_id_pre = list2id(test_list_pre)
test_id_hypo = list2id(test_list_hypo)

# %%
#save list to pickle
import pickle as pkl
pkl.dump(train_id_pre, open("train_id_pre.p", "wb"))
pkl.dump(train_id_hypo, open("train_id_hypo.p", "wb"))
pkl.dump(test_id_pre, open("test_id_pre.p", "wb"))
pkl.dump(test_id_hypo, open("test_id_hypo.p", "wb"))
pkl.dump(list(train_data_df2.y.values), open("train_y.p", "wb"))
pkl.dump(list(test_data_df2.y.values), open("test_y.p", "wb"))

# %%
def read_tokenizing_data():
    train_id_pre = pkl.load(open("train_id_pre.p", 'rb'))
    train_id_hypo = pkl.load(open("train_id_hypo.p", 'rb'))
    test_id_pre = pkl.load(open("test_id_pre.p", 'rb'))
    test_id_hypo = pkl.load(open("test_id_hypo.p", 'rb'))
    train_y = pkl.load(open("train_y.p", 'rb'))
    test_y = pkl.load(open("test_y.p", 'rb'))
    return train_id_pre, train_id_hypo, test_id_pre, test_id_hypo, train_y, test_y

# %%
train_id_pre, train_id_hypo, test_id_pre, test_id_hypo, train_y, test_y = read_tokenizing_data()

# %%
train_tuple = list(zip(train_id_pre, train_id_hypo, train_y))
test_tuple = list(zip(test_id_pre, test_id_hypo, test_y))

# %%
# top 1% length
MAX_LENGTH = sorted(len(x) for x in train_id_pre + train_id_hypo)[-int(len(train_id_pre + train_id_hypo)*0.01)]
BATCH_SIZE = 32

# %%
# build DataLoader
class SNLIDataset(Dataset):
    """
    Class that represents a train/validation/test dataset that's readable for PyTorch
    Note that this class inherits torch.utils.data.Dataset
    """

    def __init__(self, data_tuple):
        """
        @param data_list: list of character
        @param target_list: list of targets

        """
        self.data_pre_list, self.data_hypo_list, self.target_list = zip(*data_tuple)
        assert (len(self.data_pre_list) == len(self.target_list))
        assert (len(self.data_hypo_list) == len(self.target_list))

    def __len__(self):
        return len(self.target_list)

    def __getitem__(self, key):
        """
        Triggered when you call dataset[i]
        """
        char_idx1 = self.data_pre_list[key][:MAX_LENGTH]
        char_idx2 = self.data_hypo_list[key][:MAX_LENGTH]
        label = self.target_list[key]
        return [char_idx1, char_idx2, len(char_idx1), len(char_idx2), label]

def vocab_collate_func(batch):
    """
    Customized function for DataLoader that dynamically pads the batch so that all
    data have the same length
    """
    data_list_pre = []
    data_list_hypo = []
    label_list = []
    length_list_pre = []
    length_list_hypo = []

    for datum in batch:
        label_list.append(datum[4])
        length_list_pre.append(datum[2])
        length_list_hypo.append(datum[3])
    # padding
    for datum in batch:
        padded_vec_pre = np.pad(np.array(datum[0]),
                                pad_width=((0,MAX_LENGTH-datum[2])),
                                mode="constant", constant_values=0)
        padded_vec_hypo = np.pad(np.array(datum[1]),
                                pad_width = ((0, MAX_LENGTH-datum[3])), 
                                mode = "constant", constant_values= 0)
        data_list_pre.append(padded_vec_pre)
        data_list_hypo.append(padded_vec_hypo)
#     ind_dec_order_pre = np.argsort(length_list_pre)[::-1]
#     ind_dec_order_hypo = np.argsort(length_list_hypo)[::-1]
#     data_list_pre = np.array(data_list_pre)[ind_dec_order_pre]
#     data_list_hypo = np.array(data_list_pre)[ind_dec_order_hypo]
#     length_list_pre = np.array(length_list_pre)[ind_dec_order_pre]
#     length_list_hypo = np.array(length_list_hypo)[ind_dec_order_hypo]
#     label_list = np.array(label_list)[ind_dec_order]
    return [torch.from_numpy(np.array(data_list_pre)), torch.from_numpy(np.array(data_list_hypo)),
            torch.LongTensor(length_list_pre), torch.LongTensor(length_list_hypo), torch.LongTensor(label_list)]

# %%
train_dataset = SNLIDataset(train_tuple)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=BATCH_SIZE,
                                           collate_fn=vocab_collate_func,
                                           shuffle=True)

val_dataset = SNLIDataset(test_tuple)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset,
                                           batch_size=BATCH_SIZE,
                                           collate_fn=vocab_collate_func,
                                           shuffle=False)

# %%
#CNN
class CNN(nn.Module):
    def __init__(self, emb_size, hidden_size, num_layers, num_classes):

        super(CNN, self).__init__()

        self.num_layers, self.hidden_size = num_layers, hidden_size
        self.embedding = nn.Embedding.from_pretrained(torch.from_numpy(loaded_embeddings_ft).float(), freeze=True)
    
        self.conv1 = nn.Conv1d(emb_size, hidden_size, kernel_size=3, padding=1)
        self.conv2 = nn.Conv1d(hidden_size, hidden_size, kernel_size=3, padding=1)
        self.pool = nn.MaxPool1d(2, stride=2)
        self.linear1 = nn.Linear(100*2, hidden_size)
        self.linear2 = nn.Linear(hidden_size, num_classes)

    def forward(self, x1, x2, length1, length2):
        batch_size, seq_len1 = x1.size()
        _, seq_len2 = x2.size()

        embed1 = self.embedding(x1)
        hidden1 = self.conv1(embed1.transpose(1,2)).transpose(1, 2)
        hidden1 = F.relu(hidden1.contiguous().view(-1, hidden1.size(-1))).view(batch_size, seq_len1, hidden1.size(-1))

        hidden1 = self.conv2(hidden1.transpose(1,2)).transpose(1,2)
        hidden1 = F.relu(hidden1.contiguous().view(-1, hidden1.size(-1))).view(batch_size, seq_len1, hidden1.size(-1))
        hidden1 = self.pool(hidden1)
        hidden1 = torch.sum(hidden1, dim=1)
        
        embed2 = self.embedding(x2)
        hidden2 = self.conv1(embed2.transpose(1,2)).transpose(1,2)
        hidden2 = F.relu(hidden2.contiguous().view(-1, hidden2.size(-1))).view(batch_size, seq_len2, hidden2.size(-1))
        hidden2 = self.conv2(hidden2.transpose(1,2)).transpose(1,2)
        hidden2 = F.relu(hidden2.contiguous().view(-1, hidden2.size(-1))).view(batch_size, seq_len2, hidden2.size(-1))
        hidden2 = self.pool(hidden2)
        hidden2 = torch.sum(hidden2, dim=1)
    
        hidden = torch.cat((hidden1, hidden2), dim = 1)
        hidden = self.linear1(hidden)
        hidden = F.relu(hidden)
        logits = self.linear2(hidden)
        
        return logits

# %%
def test_model_cnn(loader, model):
    """
    Help function that tests the model's performance on a dataset
    @param: loader - data loader for the dataset to test against
    """
    correct = 0
    total = 0
    model.eval()
    for data1, data2, length1, length2, labels in loader:
        data1_batch, data2_batch, length1_batch, length2_batch, label_batch = data1, data2, length1, length2, labels
        outputs = F.softmax(model(data1_batch,data2_batch, length1_batch, length2_batch), dim=1)
        predicted = outputs.max(1, keepdim=True)[1]

        total += labels.size(0)
        correct += predicted.eq(labels.view_as(predicted)).sum().item()
    return (100 * correct / total)


model = CNN(emb_size=300, hidden_size=200, num_layers=2, num_classes=3)

learning_rate = 3e-4
num_epochs = 10 # number epoch to train

# Criterion and Optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Train the model
total_step = len(train_loader)

cnn_train_loss_list = []
cnn_val_acc_list = []
for epoch in range(num_epochs):
    for i, (data1, data2, length1, length2, labels) in enumerate(train_loader):
        model.train()
        optimizer.zero_grad()
        # Forward pass
        outputs = model(data1, data2, length1, length2)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        loss.backward()
        optimizer.step()
        cnn_train_loss_list.append(loss.item())
        # validate every 100 iterations
        if i > 0 and i % 100 == 0:
            # validate
            val_acc = test_model_cnn(val_loader, model)
            cnn_val_acc_list.append(val_acc)
            print('Epoch: [{}/{}], Step: [{}/{}], Validation Acc: {}'.format(
                       epoch+1, num_epochs, i+1, len(train_loader), val_acc))
# Out:
# Epoch: [1/10], Step: [101/3125], Validation Acc: 40.2
# Epoch: [1/10], Step: [201/3125], Validation Acc: 53.0
# Epoch: [1/10], Step: [301/3125], Validation Acc: 54.3
# Epoch: [1/10], Step: [401/3125], Validation Acc: 56.7
# Epoch: [1/10], Step: [501/3125], Validation Acc: 57.4
# Epoch: [1/10], Step: [601/3125], Validation Acc: 59.8
# Epoch: [1/10], Step: [701/3125], Validation Acc: 57.1
# Epoch: [1/10], Step: [801/3125], Validation Acc: 60.5
# Epoch: [1/10], Step: [901/3125], Validation Acc: 57.6
# Epoch: [1/10], Step: [1001/3125], Validation Acc: 60.4
# Epoch: [1/10], Step: [1101/3125], Validation Acc: 60.6
# Epoch: [1/10], Step: [1201/3125], Validation Acc: 59.4
# Epoch: [1/10], Step: [1301/3125], Validation Acc: 61.2
# Epoch: [1/10], Step: [1401/3125], Validation Acc: 61.6
# Epoch: [1/10], Step: [1501/3125], Validation Acc: 61.1
# Epoch: [1/10], Step: [1601/3125], Validation Acc: 63.4
# Epoch: [1/10], Step: [1701/3125], Validation Acc: 61.8
# Epoch: [1/10], Step: [1801/3125], Validation Acc: 62.6
# Epoch: [1/10], Step: [1901/3125], Validation Acc: 60.9
# Epoch: [1/10], Step: [2001/3125], Validation Acc: 62.4
# Epoch: [1/10], Step: [2101/3125], Validation Acc: 62.7
# Epoch: [1/10], Step: [2201/3125], Validation Acc: 61.8
# Epoch: [1/10], Step: [2301/3125], Validation Acc: 63.2
# Epoch: [1/10], Step: [2401/3125], Validation Acc: 62.8
# Epoch: [1/10], Step: [2501/3125], Validation Acc: 62.0
# Epoch: [1/10], Step: [2601/3125], Validation Acc: 62.4
# Epoch: [1/10], Step: [2701/3125], Validation Acc: 62.7
# Epoch: [1/10], Step: [2801/3125], Validation Acc: 63.8
# Epoch: [1/10], Step: [2901/3125], Validation Acc: 61.8
# Epoch: [1/10], Step: [3001/3125], Validation Acc: 63.9
# Epoch: [1/10], Step: [3101/3125], Validation Acc: 64.1
# Epoch: [2/10], Step: [101/3125], Validation Acc: 63.3
# Epoch: [2/10], Step: [201/3125], Validation Acc: 64.3
# Epoch: [2/10], Step: [301/3125], Validation Acc: 64.6
# Epoch: [2/10], Step: [401/3125], Validation Acc: 64.2
# Epoch: [2/10], Step: [501/3125], Validation Acc: 64.3
# Epoch: [2/10], Step: [601/3125], Validation Acc: 64.8
# Epoch: [2/10], Step: [701/3125], Validation Acc: 65.3
# Epoch: [2/10], Step: [801/3125], Validation Acc: 64.4
# Epoch: [2/10], Step: [901/3125], Validation Acc: 64.7
# Epoch: [2/10], Step: [1001/3125], Validation Acc: 66.0
# Epoch: [2/10], Step: [1101/3125], Validation Acc: 65.6
# Epoch: [2/10], Step: [1201/3125], Validation Acc: 65.4
# Epoch: [2/10], Step: [1301/3125], Validation Acc: 65.5
# Epoch: [2/10], Step: [1401/3125], Validation Acc: 65.4
# Epoch: [2/10], Step: [1501/3125], Validation Acc: 65.3
# Epoch: [2/10], Step: [1601/3125], Validation Acc: 64.5
# Epoch: [2/10], Step: [1701/3125], Validation Acc: 67.2
# Epoch: [2/10], Step: [1801/3125], Validation Acc: 67.2
# Epoch: [2/10], Step: [1901/3125], Validation Acc: 66.4
# Epoch: [2/10], Step: [2001/3125], Validation Acc: 66.0
# Epoch: [2/10], Step: [2101/3125], Validation Acc: 67.8
# Epoch: [2/10], Step: [2201/3125], Validation Acc: 65.4
# Epoch: [2/10], Step: [2301/3125], Validation Acc: 67.4
# Epoch: [2/10], Step: [2401/3125], Validation Acc: 66.4
# Epoch: [2/10], Step: [2501/3125], Validation Acc: 68.4
# Epoch: [2/10], Step: [2601/3125], Validation Acc: 67.0
# Epoch: [2/10], Step: [2701/3125], Validation Acc: 67.0
# Epoch: [2/10], Step: [2801/3125], Validation Acc: 68.4
# Epoch: [2/10], Step: [2901/3125], Validation Acc: 68.9
# Epoch: [2/10], Step: [3001/3125], Validation Acc: 67.7
# Epoch: [2/10], Step: [3101/3125], Validation Acc: 66.6
# Epoch: [3/10], Step: [101/3125], Validation Acc: 67.9
# Epoch: [3/10], Step: [201/3125], Validation Acc: 69.0
# Epoch: [3/10], Step: [301/3125], Validation Acc: 68.7
# Epoch: [3/10], Step: [401/3125], Validation Acc: 66.9
# Epoch: [3/10], Step: [501/3125], Validation Acc: 66.6
# Epoch: [3/10], Step: [601/3125], Validation Acc: 67.8
# Epoch: [3/10], Step: [701/3125], Validation Acc: 67.9
# Epoch: [3/10], Step: [801/3125], Validation Acc: 68.0
# Epoch: [3/10], Step: [901/3125], Validation Acc: 67.8
# Epoch: [3/10], Step: [1001/3125], Validation Acc: 67.3
# Epoch: [3/10], Step: [1101/3125], Validation Acc: 68.0
# Epoch: [3/10], Step: [1201/3125], Validation Acc: 69.1
# Epoch: [3/10], Step: [1301/3125], Validation Acc: 68.6
# Epoch: [3/10], Step: [1401/3125], Validation Acc: 68.5
# Epoch: [3/10], Step: [1501/3125], Validation Acc: 68.6
# Epoch: [3/10], Step: [1601/3125], Validation Acc: 66.8
# Epoch: [3/10], Step: [1701/3125], Validation Acc: 68.8
# Epoch: [3/10], Step: [1801/3125], Validation Acc: 67.6
# Epoch: [3/10], Step: [1901/3125], Validation Acc: 67.2
# Epoch: [3/10], Step: [2001/3125], Validation Acc: 68.2
# Epoch: [3/10], Step: [2101/3125], Validation Acc: 68.4
# Epoch: [3/10], Step: [2201/3125], Validation Acc: 68.7
# Epoch: [3/10], Step: [2301/3125], Validation Acc: 69.0
# Epoch: [3/10], Step: [2401/3125], Validation Acc: 68.1
# Epoch: [3/10], Step: [2501/3125], Validation Acc: 67.9
# Epoch: [3/10], Step: [2601/3125], Validation Acc: 68.6
# Epoch: [3/10], Step: [2701/3125], Validation Acc: 68.2
# Epoch: [3/10], Step: [2801/3125], Validation Acc: 68.1
# Epoch: [3/10], Step: [2901/3125], Validation Acc: 67.2
# Epoch: [3/10], Step: [3001/3125], Validation Acc: 67.7
# Epoch: [3/10], Step: [3101/3125], Validation Acc: 69.3
# Epoch: [4/10], Step: [101/3125], Validation Acc: 69.9
# Epoch: [4/10], Step: [201/3125], Validation Acc: 68.9
# Epoch: [4/10], Step: [301/3125], Validation Acc: 69.0
# Epoch: [4/10], Step: [401/3125], Validation Acc: 67.2
# Epoch: [4/10], Step: [501/3125], Validation Acc: 70.0
# Epoch: [4/10], Step: [601/3125], Validation Acc: 69.0
# Epoch: [4/10], Step: [701/3125], Validation Acc: 69.2
# Epoch: [4/10], Step: [801/3125], Validation Acc: 69.8
# Epoch: [4/10], Step: [901/3125], Validation Acc: 69.3
# Epoch: [4/10], Step: [1001/3125], Validation Acc: 69.3
# Epoch: [4/10], Step: [1101/3125], Validation Acc: 69.4
# Epoch: [4/10], Step: [1201/3125], Validation Acc: 68.8
# Epoch: [4/10], Step: [1301/3125], Validation Acc: 69.1
# Epoch: [4/10], Step: [1401/3125], Validation Acc: 68.0
# Epoch: [4/10], Step: [1501/3125], Validation Acc: 67.8
# Epoch: [4/10], Step: [1601/3125], Validation Acc: 68.5
# Epoch: [4/10], Step: [1701/3125], Validation Acc: 68.7
# Epoch: [4/10], Step: [1801/3125], Validation Acc: 69.3
# Epoch: [4/10], Step: [1901/3125], Validation Acc: 69.8
# Epoch: [4/10], Step: [2001/3125], Validation Acc: 68.7
# Epoch: [4/10], Step: [2101/3125], Validation Acc: 69.2
# Epoch: [4/10], Step: [2201/3125], Validation Acc: 70.2
# Epoch: [4/10], Step: [2301/3125], Validation Acc: 69.5
# Epoch: [4/10], Step: [2401/3125], Validation Acc: 70.5
# Epoch: [4/10], Step: [2501/3125], Validation Acc: 69.6
# Epoch: [4/10], Step: [2601/3125], Validation Acc: 69.7
# Epoch: [4/10], Step: [2701/3125], Validation Acc: 68.5
# Epoch: [4/10], Step: [2801/3125], Validation Acc: 69.3
# Epoch: [4/10], Step: [2901/3125], Validation Acc: 69.4
# Epoch: [4/10], Step: [3001/3125], Validation Acc: 69.6
# Epoch: [4/10], Step: [3101/3125], Validation Acc: 68.6
# Epoch: [5/10], Step: [101/3125], Validation Acc: 69.6
# Epoch: [5/10], Step: [201/3125], Validation Acc: 69.8
# Epoch: [5/10], Step: [301/3125], Validation Acc: 68.8
# Epoch: [5/10], Step: [401/3125], Validation Acc: 68.8
# Epoch: [5/10], Step: [501/3125], Validation Acc: 68.9
# Epoch: [5/10], Step: [601/3125], Validation Acc: 70.3
# Epoch: [5/10], Step: [701/3125], Validation Acc: 70.8
# Epoch: [5/10], Step: [801/3125], Validation Acc: 69.8
# Epoch: [5/10], Step: [901/3125], Validation Acc: 69.4
# Epoch: [5/10], Step: [1001/3125], Validation Acc: 70.0
# Epoch: [5/10], Step: [1101/3125], Validation Acc: 68.2
# Epoch: [5/10], Step: [1201/3125], Validation Acc: 69.5
# Epoch: [5/10], Step: [1301/3125], Validation Acc: 69.2
# Epoch: [5/10], Step: [1401/3125], Validation Acc: 70.0
# Epoch: [5/10], Step: [1501/3125], Validation Acc: 69.2
# Epoch: [5/10], Step: [1601/3125], Validation Acc: 68.4
# Epoch: [5/10], Step: [1701/3125], Validation Acc: 69.5
# Epoch: [5/10], Step: [1801/3125], Validation Acc: 68.3
# Epoch: [5/10], Step: [1901/3125], Validation Acc: 68.4
# Epoch: [5/10], Step: [2001/3125], Validation Acc: 69.1
# Epoch: [5/10], Step: [2101/3125], Validation Acc: 69.7
# Epoch: [5/10], Step: [2201/3125], Validation Acc: 70.6
# Epoch: [5/10], Step: [2301/3125], Validation Acc: 69.5
# Epoch: [5/10], Step: [2401/3125], Validation Acc: 68.7
# Epoch: [5/10], Step: [2501/3125], Validation Acc: 69.0
# Epoch: [5/10], Step: [2601/3125], Validation Acc: 69.1
# Epoch: [5/10], Step: [2701/3125], Validation Acc: 68.5
# Epoch: [5/10], Step: [2801/3125], Validation Acc: 69.4
# Epoch: [5/10], Step: [2901/3125], Validation Acc: 68.7
# Epoch: [5/10], Step: [3001/3125], Validation Acc: 68.8
# Epoch: [5/10], Step: [3101/3125], Validation Acc: 69.9
# Epoch: [6/10], Step: [101/3125], Validation Acc: 70.8
# Epoch: [6/10], Step: [201/3125], Validation Acc: 70.1
# Epoch: [6/10], Step: [301/3125], Validation Acc: 70.1
# Epoch: [6/10], Step: [401/3125], Validation Acc: 69.3
# Epoch: [6/10], Step: [501/3125], Validation Acc: 68.8
# Epoch: [6/10], Step: [601/3125], Validation Acc: 70.0
# Epoch: [6/10], Step: [701/3125], Validation Acc: 70.2
# Epoch: [6/10], Step: [801/3125], Validation Acc: 69.0
# Epoch: [6/10], Step: [901/3125], Validation Acc: 70.0
# Epoch: [6/10], Step: [1001/3125], Validation Acc: 70.4
# Epoch: [6/10], Step: [1101/3125], Validation Acc: 69.8
# Epoch: [6/10], Step: [1201/3125], Validation Acc: 69.6
# Epoch: [6/10], Step: [1301/3125], Validation Acc: 71.0
# Epoch: [6/10], Step: [1401/3125], Validation Acc: 70.5
# Epoch: [6/10], Step: [1501/3125], Validation Acc: 70.6
# Epoch: [6/10], Step: [1601/3125], Validation Acc: 70.0
# Epoch: [6/10], Step: [1701/3125], Validation Acc: 69.8
# Epoch: [6/10], Step: [1801/3125], Validation Acc: 67.3
# Epoch: [6/10], Step: [1901/3125], Validation Acc: 70.5
# Epoch: [6/10], Step: [2001/3125], Validation Acc: 70.0
# Epoch: [6/10], Step: [2101/3125], Validation Acc: 70.2
# Epoch: [6/10], Step: [2201/3125], Validation Acc: 70.2
# Epoch: [6/10], Step: [2301/3125], Validation Acc: 70.3
# Epoch: [6/10], Step: [2401/3125], Validation Acc: 70.4
# Epoch: [6/10], Step: [2501/3125], Validation Acc: 69.1
# Epoch: [6/10], Step: [2601/3125], Validation Acc: 69.6
# Epoch: [6/10], Step: [2701/3125], Validation Acc: 70.8
# Epoch: [6/10], Step: [2801/3125], Validation Acc: 71.5
# Epoch: [6/10], Step: [2901/3125], Validation Acc: 69.8
# Epoch: [6/10], Step: [3001/3125], Validation Acc: 68.5
# Epoch: [6/10], Step: [3101/3125], Validation Acc: 69.4
# Epoch: [7/10], Step: [101/3125], Validation Acc: 68.6
# Epoch: [7/10], Step: [201/3125], Validation Acc: 68.9
# Epoch: [7/10], Step: [301/3125], Validation Acc: 69.3
# Epoch: [7/10], Step: [401/3125], Validation Acc: 69.1
# Epoch: [7/10], Step: [501/3125], Validation Acc: 70.0
# Epoch: [7/10], Step: [601/3125], Validation Acc: 69.9
# Epoch: [7/10], Step: [701/3125], Validation Acc: 69.1
# Epoch: [7/10], Step: [801/3125], Validation Acc: 69.4
# Epoch: [7/10], Step: [901/3125], Validation Acc: 70.9
# Epoch: [7/10], Step: [1001/3125], Validation Acc: 69.6
# Epoch: [7/10], Step: [1101/3125], Validation Acc: 69.3
# Epoch: [7/10], Step: [1201/3125], Validation Acc: 69.3
# Epoch: [7/10], Step: [1301/3125], Validation Acc: 67.0
# Epoch: [7/10], Step: [1401/3125], Validation Acc: 68.5
# Epoch: [7/10], Step: [1501/3125], Validation Acc: 70.3
# Epoch: [7/10], Step: [1601/3125], Validation Acc: 69.1
# Epoch: [7/10], Step: [1701/3125], Validation Acc: 69.6
# Epoch: [7/10], Step: [1801/3125], Validation Acc: 70.5
# Epoch: [7/10], Step: [1901/3125], Validation Acc: 70.0
# Epoch: [7/10], Step: [2001/3125], Validation Acc: 70.8
# Epoch: [7/10], Step: [2101/3125], Validation Acc: 70.0
# Epoch: [7/10], Step: [2201/3125], Validation Acc: 69.7
# Epoch: [7/10], Step: [2301/3125], Validation Acc: 69.4
# Epoch: [7/10], Step: [2401/3125], Validation Acc: 69.7
# Epoch: [7/10], Step: [2501/3125], Validation Acc: 69.5
# Epoch: [7/10], Step: [2601/3125], Validation Acc: 70.1
# Epoch: [7/10], Step: [2701/3125], Validation Acc: 69.0
# Epoch: [7/10], Step: [2801/3125], Validation Acc: 70.0
# Epoch: [7/10], Step: [2901/3125], Validation Acc: 69.2
# Epoch: [7/10], Step: [3001/3125], Validation Acc: 68.6
# Epoch: [7/10], Step: [3101/3125], Validation Acc: 69.9
# Epoch: [8/10], Step: [101/3125], Validation Acc: 70.4
# Epoch: [8/10], Step: [201/3125], Validation Acc: 69.0
# Epoch: [8/10], Step: [301/3125], Validation Acc: 70.3
# Epoch: [8/10], Step: [401/3125], Validation Acc: 70.1
# Epoch: [8/10], Step: [501/3125], Validation Acc: 69.5
# Epoch: [8/10], Step: [601/3125], Validation Acc: 69.5
# Epoch: [8/10], Step: [701/3125], Validation Acc: 68.8
# Epoch: [8/10], Step: [801/3125], Validation Acc: 68.8
# Epoch: [8/10], Step: [901/3125], Validation Acc: 69.0
# Epoch: [8/10], Step: [1001/3125], Validation Acc: 68.6
# Epoch: [8/10], Step: [1101/3125], Validation Acc: 69.1
# Epoch: [8/10], Step: [1201/3125], Validation Acc: 69.5
# Epoch: [8/10], Step: [1301/3125], Validation Acc: 69.5
# Epoch: [8/10], Step: [1401/3125], Validation Acc: 68.7
# Epoch: [8/10], Step: [1501/3125], Validation Acc: 69.7
# Epoch: [8/10], Step: [1601/3125], Validation Acc: 70.1
# Epoch: [8/10], Step: [1701/3125], Validation Acc: 69.1
# Epoch: [8/10], Step: [1801/3125], Validation Acc: 70.1
# Epoch: [8/10], Step: [1901/3125], Validation Acc: 69.9
# Epoch: [8/10], Step: [2001/3125], Validation Acc: 70.5
# Epoch: [8/10], Step: [2101/3125], Validation Acc: 70.0
# Epoch: [8/10], Step: [2201/3125], Validation Acc: 69.9
# Epoch: [8/10], Step: [2301/3125], Validation Acc: 69.9
# Epoch: [8/10], Step: [2401/3125], Validation Acc: 69.2
# Epoch: [8/10], Step: [2501/3125], Validation Acc: 70.6
# Epoch: [8/10], Step: [2601/3125], Validation Acc: 70.1
# Epoch: [8/10], Step: [2701/3125], Validation Acc: 69.5
# Epoch: [8/10], Step: [2801/3125], Validation Acc: 70.4
# Epoch: [8/10], Step: [2901/3125], Validation Acc: 69.6
# Epoch: [8/10], Step: [3001/3125], Validation Acc: 69.0
# Epoch: [8/10], Step: [3101/3125], Validation Acc: 68.2
# Epoch: [9/10], Step: [101/3125], Validation Acc: 69.4
# Epoch: [9/10], Step: [201/3125], Validation Acc: 70.2
# Epoch: [9/10], Step: [301/3125], Validation Acc: 70.0
# Epoch: [9/10], Step: [401/3125], Validation Acc: 68.8
# Epoch: [9/10], Step: [501/3125], Validation Acc: 68.4
# Epoch: [9/10], Step: [601/3125], Validation Acc: 69.5
# Epoch: [9/10], Step: [701/3125], Validation Acc: 70.1
# Epoch: [9/10], Step: [801/3125], Validation Acc: 69.4
# Epoch: [9/10], Step: [901/3125], Validation Acc: 68.8
# Epoch: [9/10], Step: [1001/3125], Validation Acc: 68.1
# Epoch: [9/10], Step: [1101/3125], Validation Acc: 69.4
# Epoch: [9/10], Step: [1201/3125], Validation Acc: 69.4
# Epoch: [9/10], Step: [1301/3125], Validation Acc: 69.3
# Epoch: [9/10], Step: [1401/3125], Validation Acc: 68.4
# Epoch: [9/10], Step: [1501/3125], Validation Acc: 69.5
# Epoch: [9/10], Step: [1601/3125], Validation Acc: 70.4
# Epoch: [9/10], Step: [1701/3125], Validation Acc: 70.3
# Epoch: [9/10], Step: [1801/3125], Validation Acc: 71.2
# Epoch: [9/10], Step: [1901/3125], Validation Acc: 71.4
# Epoch: [9/10], Step: [2001/3125], Validation Acc: 70.1
# Epoch: [9/10], Step: [2101/3125], Validation Acc: 69.7
# Epoch: [9/10], Step: [2201/3125], Validation Acc: 68.2
# Epoch: [9/10], Step: [2301/3125], Validation Acc: 69.5
# Epoch: [9/10], Step: [2401/3125], Validation Acc: 69.4
# Epoch: [9/10], Step: [2501/3125], Validation Acc: 69.3
# Epoch: [9/10], Step: [2601/3125], Validation Acc: 69.3
# Epoch: [9/10], Step: [2701/3125], Validation Acc: 69.2
# Epoch: [9/10], Step: [2801/3125], Validation Acc: 69.5
# Epoch: [9/10], Step: [2901/3125], Validation Acc: 70.3
# Epoch: [9/10], Step: [3001/3125], Validation Acc: 70.8
# Epoch: [9/10], Step: [3101/3125], Validation Acc: 69.2
# Epoch: [10/10], Step: [101/3125], Validation Acc: 69.6
# Epoch: [10/10], Step: [201/3125], Validation Acc: 69.6
# Epoch: [10/10], Step: [301/3125], Validation Acc: 69.7
# Epoch: [10/10], Step: [401/3125], Validation Acc: 69.0
# Epoch: [10/10], Step: [501/3125], Validation Acc: 69.4
# Epoch: [10/10], Step: [601/3125], Validation Acc: 68.8
# Epoch: [10/10], Step: [701/3125], Validation Acc: 68.3
# Epoch: [10/10], Step: [801/3125], Validation Acc: 69.2
# Epoch: [10/10], Step: [901/3125], Validation Acc: 68.3
# Epoch: [10/10], Step: [1001/3125], Validation Acc: 69.6
# Epoch: [10/10], Step: [1101/3125], Validation Acc: 70.4
# Epoch: [10/10], Step: [1201/3125], Validation Acc: 69.9
# Epoch: [10/10], Step: [1301/3125], Validation Acc: 69.7
# Epoch: [10/10], Step: [1401/3125], Validation Acc: 69.1
# Epoch: [10/10], Step: [1501/3125], Validation Acc: 69.7
# Epoch: [10/10], Step: [1601/3125], Validation Acc: 68.9
# Epoch: [10/10], Step: [1701/3125], Validation Acc: 68.4
# Epoch: [10/10], Step: [1801/3125], Validation Acc: 68.6
# Epoch: [10/10], Step: [1901/3125], Validation Acc: 68.6
# Epoch: [10/10], Step: [2001/3125], Validation Acc: 69.2
# Epoch: [10/10], Step: [2101/3125], Validation Acc: 70.1
# Epoch: [10/10], Step: [2201/3125], Validation Acc: 69.6
# Epoch: [10/10], Step: [2301/3125], Validation Acc: 70.1
# Epoch: [10/10], Step: [2401/3125], Validation Acc: 68.7
# Epoch: [10/10], Step: [2501/3125], Validation Acc: 69.0
# Epoch: [10/10], Step: [2601/3125], Validation Acc: 69.2
# Epoch: [10/10], Step: [2701/3125], Validation Acc: 68.5
# Epoch: [10/10], Step: [2801/3125], Validation Acc: 69.1
# Epoch: [10/10], Step: [2901/3125], Validation Acc: 70.0
# Epoch: [10/10], Step: [3001/3125], Validation Acc: 68.8
# Epoch: [10/10], Step: [3101/3125], Validation Acc: 69.7

# %%
class RNN(nn.Module):
    def __init__(self, emb_size, hidden_size, num_layers, num_classes, linear_size):
        super(RNN, self).__init__()
        
        self.num_layers, self.hidden_size = num_layers, hidden_size
        self.embedding = nn.Embedding.from_pretrained(torch.from_numpy(loaded_embeddings_ft).float(), freeze=True)
        self.rnn = nn.RNN(emb_size, hidden_size, num_layers, batch_first=True)
        self.gru = nn.GRU(hidden_size, hidden_size, num_layers=1, batch_first=False,bidirectional=True)
        self.linear1 = nn.Linear(hidden_size*2, linear_size)
        self.linear2 = nn.Linear(linear_size, num_classes)
        
    def init_hidden(self, batch_size):
        # Function initializes the activation of recurrent neural net at timestep 0
        # Needs to be in format (num_layers, batch_size, hidden_size)
        if torch.cuda.is_available and torch.has_cudnn:
            hidden = torch.randn(self.num_layers, batch_size, self.hidden_size).cuda()
        else:
            hidden = torch.randn(self.num_layers, batch_size, self.hidden_size)
        return hidden
    
    def forward(self, x1, x2, length1, length2):
        # reset hidden state

        batch_size, seq_len1 = x1.size()
        _, seq_len2 = x2.size()

        self.hidden1 = self.init_hidden(batch_size)
        self.hidden2 = self.init_hidden(batch_size)
        _, idx_sort1 = torch.sort(length1, dim=0, descending=True)
        _, idx_sort2 = torch.sort(length2, dim=0, descending=True)
        
        #unsort ?
        _, idx_unsort1 = torch.sort(idx_sort1, dim=0)
        _, idx_unsort2 = torch.sort(idx_sort2, dim=0)

        # get embedding of characters
        embed1 = self.embedding(x1)
        embed2 = self.embedding(x2)
        
        # sort embedding
        embed1 = embed1.index_select(0, idx_sort1)
        embed2 = embed2.index_select(0, idx_sort2)
        sorted_len1 = length1[idx_sort1]
        sorted_len2 = length2[idx_sort2]
        
        # pack padded sequence
        embed1 = torch.nn.utils.rnn.pack_padded_sequence(embed1, sorted_len1.numpy(), batch_first=True)
        embed2 = torch.nn.utils.rnn.pack_padded_sequence(embed2, sorted_len2.numpy(), batch_first=True)
        # fprop though RNN
        rnn_out1, self.hidden1 = self.rnn(embed1, self.hidden1)
        rnn_out2, self.hidden2 = self.rnn(embed2, self.hidden2)
        
        # sum hidden activations of RNN across time
        rnn_out1 = torch.sum(self.hidden1, dim=0)
        rnn_out2 = torch.sum(self.hidden2, dim=0)
        
        #unsort
        output1 = rnn_out1.index_select(0, idx_unsort1)
        output2 = rnn_out2.index_select(0, idx_unsort2)
        
        #concat
        hidden3 = torch.cat((output1, output2), dim = 1)
        
        hidden3 = self.linear1(hidden3)
        hidden3 = F.relu(hidden3)
        logits = self.linear2(hidden3)

        return logits

# %%
def test_model_rnn(loader, model):
    """
    Help function that tests the model's performance on a dataset
    @param: loader - data loader for the dataset to test against
    """
    correct = 0
    total = 0
    model.eval()
    for data1, data2, length1, length2, labels in loader:
        data1_batch, data2_batch, length1_batch, length2_batch, label_batch = data1, data2, length1, length2, labels
        outputs = F.softmax(model(data1_batch,data2_batch, length1_batch, length2_batch), dim=1)
        predicted = outputs.max(1, keepdim=True)[1]

        total += labels.size(0)
        correct += predicted.eq(labels.view_as(predicted)).sum().item()
    return (100 * correct / total)

if torch.cuda.is_available and torch.has_cudnn:
    model = RNN(emb_size=300, hidden_size=200, num_layers=2, num_classes=3, linear_size=200).cuda()
else:
    model = RNN(emb_size=300, hidden_size=200, num_layers=2, num_classes=3, linear_size=200)

learning_rate = 3e-4
num_epochs = 10 # number epoch to train

# Criterion and Optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Train the model
total_step = len(train_loader)

rnn_train_loss_list = []
rnn_val_acc_list = []
for epoch in range(num_epochs):
    for i, (data1, data2, length1, length2, labels) in enumerate(train_loader):
        model.train()
        optimizer.zero_grad()
        # Forward pass
        outputs = model(data1, data2, length1, length2)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        loss.backward()
        optimizer.step()
        rnn_train_loss_list.append(loss.item())
        # validate every 100 iterations
        if i > 0 and i % 100 == 0:
            # validate
            val_acc = test_model_rnn(val_loader, model)
            rnn_val_acc_list.append(val_acc)
            print('Epoch: [{}/{}], Step: [{}/{}], Validation Acc: {}'.format(
                       epoch+1, num_epochs, i+1, len(train_loader), val_acc))
# Out:
# Epoch: [1/10], Step: [101/3125], Validation Acc: 38.8
# Epoch: [1/10], Step: [201/3125], Validation Acc: 46.8
# Epoch: [1/10], Step: [301/3125], Validation Acc: 50.4
# Epoch: [1/10], Step: [401/3125], Validation Acc: 47.5
# Epoch: [1/10], Step: [501/3125], Validation Acc: 52.1
# Epoch: [1/10], Step: [601/3125], Validation Acc: 51.4
# Epoch: [1/10], Step: [701/3125], Validation Acc: 53.5
# Epoch: [1/10], Step: [801/3125], Validation Acc: 52.8
# Epoch: [1/10], Step: [901/3125], Validation Acc: 55.6
# Epoch: [1/10], Step: [1001/3125], Validation Acc: 54.4
# Epoch: [1/10], Step: [1101/3125], Validation Acc: 55.7
# Epoch: [1/10], Step: [1201/3125], Validation Acc: 54.5
# Epoch: [1/10], Step: [1301/3125], Validation Acc: 54.9
# Epoch: [1/10], Step: [1401/3125], Validation Acc: 54.0
# Epoch: [1/10], Step: [1501/3125], Validation Acc: 55.1
# Epoch: [1/10], Step: [1601/3125], Validation Acc: 53.5
# Epoch: [1/10], Step: [1701/3125], Validation Acc: 53.5
# Epoch: [1/10], Step: [1801/3125], Validation Acc: 53.7
# Epoch: [1/10], Step: [1901/3125], Validation Acc: 54.2
# Epoch: [1/10], Step: [2001/3125], Validation Acc: 55.3
# Epoch: [1/10], Step: [2101/3125], Validation Acc: 54.4
# Epoch: [1/10], Step: [2201/3125], Validation Acc: 57.2
# Epoch: [1/10], Step: [2301/3125], Validation Acc: 55.6
# Epoch: [1/10], Step: [2401/3125], Validation Acc: 57.6
# Epoch: [1/10], Step: [2501/3125], Validation Acc: 55.2
# Epoch: [1/10], Step: [2601/3125], Validation Acc: 55.8
# Epoch: [1/10], Step: [2701/3125], Validation Acc: 55.9
# Epoch: [1/10], Step: [2801/3125], Validation Acc: 55.2
# Epoch: [1/10], Step: [2901/3125], Validation Acc: 57.0
# Epoch: [1/10], Step: [3001/3125], Validation Acc: 56.3
# Epoch: [1/10], Step: [3101/3125], Validation Acc: 56.5
# Epoch: [2/10], Step: [101/3125], Validation Acc: 52.5
# Epoch: [2/10], Step: [201/3125], Validation Acc: 55.7
# Epoch: [2/10], Step: [301/3125], Validation Acc: 59.3
# Epoch: [2/10], Step: [401/3125], Validation Acc: 57.0
# Epoch: [2/10], Step: [501/3125], Validation Acc: 55.8
# Epoch: [2/10], Step: [601/3125], Validation Acc: 57.9
# Epoch: [2/10], Step: [701/3125], Validation Acc: 57.3
# Epoch: [2/10], Step: [801/3125], Validation Acc: 56.6
# Epoch: [2/10], Step: [901/3125], Validation Acc: 57.0
# Epoch: [2/10], Step: [1001/3125], Validation Acc: 57.6
# Epoch: [2/10], Step: [1101/3125], Validation Acc: 57.1
# Epoch: [2/10], Step: [1201/3125], Validation Acc: 58.6
# Epoch: [2/10], Step: [1301/3125], Validation Acc: 56.7
# Epoch: [2/10], Step: [1401/3125], Validation Acc: 57.8
# Epoch: [2/10], Step: [1501/3125], Validation Acc: 58.1
# Epoch: [2/10], Step: [1601/3125], Validation Acc: 58.0
# Epoch: [2/10], Step: [1701/3125], Validation Acc: 59.1
# Epoch: [2/10], Step: [1801/3125], Validation Acc: 55.8
# Epoch: [2/10], Step: [1901/3125], Validation Acc: 59.2
# Epoch: [2/10], Step: [2001/3125], Validation Acc: 59.6
# Epoch: [2/10], Step: [2101/3125], Validation Acc: 58.3
# Epoch: [2/10], Step: [2201/3125], Validation Acc: 58.8
# Epoch: [2/10], Step: [2301/3125], Validation Acc: 58.8
# Epoch: [2/10], Step: [2401/3125], Validation Acc: 58.9
# Epoch: [2/10], Step: [2501/3125], Validation Acc: 58.6
# Epoch: [2/10], Step: [2601/3125], Validation Acc: 58.0
# Epoch: [2/10], Step: [2701/3125], Validation Acc: 59.5
# Epoch: [2/10], Step: [2801/3125], Validation Acc: 62.0
# Epoch: [2/10], Step: [2901/3125], Validation Acc: 58.7
# Epoch: [2/10], Step: [3001/3125], Validation Acc: 59.0
# Epoch: [2/10], Step: [3101/3125], Validation Acc: 58.8
# Epoch: [3/10], Step: [101/3125], Validation Acc: 59.2
# Epoch: [3/10], Step: [201/3125], Validation Acc: 59.9
# Epoch: [3/10], Step: [301/3125], Validation Acc: 61.2
# Epoch: [3/10], Step: [401/3125], Validation Acc: 58.9
# Epoch: [3/10], Step: [501/3125], Validation Acc: 59.8
# Epoch: [3/10], Step: [601/3125], Validation Acc: 60.2
# Epoch: [3/10], Step: [701/3125], Validation Acc: 58.2
# Epoch: [3/10], Step: [801/3125], Validation Acc: 60.1
# Epoch: [3/10], Step: [901/3125], Validation Acc: 60.7
# Epoch: [3/10], Step: [1001/3125], Validation Acc: 59.9
# Epoch: [3/10], Step: [1101/3125], Validation Acc: 59.4
# Epoch: [3/10], Step: [1201/3125], Validation Acc: 61.0
# Epoch: [3/10], Step: [1301/3125], Validation Acc: 60.2
# Epoch: [3/10], Step: [1401/3125], Validation Acc: 60.9
# Epoch: [3/10], Step: [1501/3125], Validation Acc: 60.4
# Epoch: [3/10], Step: [1601/3125], Validation Acc: 61.2
# Epoch: [3/10], Step: [1701/3125], Validation Acc: 61.5
# Epoch: [3/10], Step: [1801/3125], Validation Acc: 60.0
# Epoch: [3/10], Step: [1901/3125], Validation Acc: 62.6
# Epoch: [3/10], Step: [2001/3125], Validation Acc: 63.1
# Epoch: [3/10], Step: [2101/3125], Validation Acc: 60.4
# Epoch: [3/10], Step: [2201/3125], Validation Acc: 60.8
# Epoch: [3/10], Step: [2301/3125], Validation Acc: 61.9
# Epoch: [3/10], Step: [2401/3125], Validation Acc: 61.9
# Epoch: [3/10], Step: [2501/3125], Validation Acc: 63.5
# Epoch: [3/10], Step: [2601/3125], Validation Acc: 62.7
# Epoch: [3/10], Step: [2701/3125], Validation Acc: 62.3
# Epoch: [3/10], Step: [2801/3125], Validation Acc: 61.7
# Epoch: [3/10], Step: [2901/3125], Validation Acc: 63.0
# Epoch: [3/10], Step: [3001/3125], Validation Acc: 61.8
# Epoch: [3/10], Step: [3101/3125], Validation Acc: 62.1
# Epoch: [4/10], Step: [101/3125], Validation Acc: 62.7
# Epoch: [4/10], Step: [201/3125], Validation Acc: 63.2
# Epoch: [4/10], Step: [301/3125], Validation Acc: 61.4
# Epoch: [4/10], Step: [401/3125], Validation Acc: 62.2
# Epoch: [4/10], Step: [501/3125], Validation Acc: 63.3
# Epoch: [4/10], Step: [601/3125], Validation Acc: 63.6
# Epoch: [4/10], Step: [701/3125], Validation Acc: 60.9
# Epoch: [4/10], Step: [801/3125], Validation Acc: 62.6
# Epoch: [4/10], Step: [901/3125], Validation Acc: 60.5
# Epoch: [4/10], Step: [1001/3125], Validation Acc: 63.2
# Epoch: [4/10], Step: [1101/3125], Validation Acc: 64.2
# Epoch: [4/10], Step: [1201/3125], Validation Acc: 63.6
# Epoch: [4/10], Step: [1301/3125], Validation Acc: 64.8
# Epoch: [4/10], Step: [1401/3125], Validation Acc: 63.1
# Epoch: [4/10], Step: [1501/3125], Validation Acc: 63.9
# Epoch: [4/10], Step: [1601/3125], Validation Acc: 62.9
# Epoch: [4/10], Step: [1701/3125], Validation Acc: 62.2
# Epoch: [4/10], Step: [1801/3125], Validation Acc: 62.1
# Epoch: [4/10], Step: [1901/3125], Validation Acc: 61.0
# Epoch: [4/10], Step: [2001/3125], Validation Acc: 62.7
# Epoch: [4/10], Step: [2101/3125], Validation Acc: 63.1
# Epoch: [4/10], Step: [2201/3125], Validation Acc: 64.4
# Epoch: [4/10], Step: [2301/3125], Validation Acc: 63.2
# Epoch: [4/10], Step: [2401/3125], Validation Acc: 64.1
# Epoch: [4/10], Step: [2501/3125], Validation Acc: 61.9
# Epoch: [4/10], Step: [2601/3125], Validation Acc: 64.6
# Epoch: [4/10], Step: [2701/3125], Validation Acc: 63.9
# Epoch: [4/10], Step: [2801/3125], Validation Acc: 64.5
# Epoch: [4/10], Step: [2901/3125], Validation Acc: 64.8
# Epoch: [4/10], Step: [3001/3125], Validation Acc: 65.0
# Epoch: [4/10], Step: [3101/3125], Validation Acc: 63.5
# Epoch: [5/10], Step: [101/3125], Validation Acc: 63.2
# Epoch: [5/10], Step: [201/3125], Validation Acc: 63.5
# Epoch: [5/10], Step: [301/3125], Validation Acc: 63.8
# Epoch: [5/10], Step: [401/3125], Validation Acc: 63.4
# Epoch: [5/10], Step: [501/3125], Validation Acc: 64.3
# Epoch: [5/10], Step: [601/3125], Validation Acc: 62.2
# Epoch: [5/10], Step: [701/3125], Validation Acc: 63.5
# Epoch: [5/10], Step: [801/3125], Validation Acc: 64.4
# Epoch: [5/10], Step: [901/3125], Validation Acc: 65.6
# Epoch: [5/10], Step: [1001/3125], Validation Acc: 65.3
# Epoch: [5/10], Step: [1101/3125], Validation Acc: 64.6
# Epoch: [5/10], Step: [1201/3125], Validation Acc: 63.8
# Epoch: [5/10], Step: [1301/3125], Validation Acc: 63.9
# Epoch: [5/10], Step: [1401/3125], Validation Acc: 63.9
# Epoch: [5/10], Step: [1501/3125], Validation Acc: 64.6
# Epoch: [5/10], Step: [1601/3125], Validation Acc: 64.6
# Epoch: [5/10], Step: [1701/3125], Validation Acc: 65.1
# Epoch: [5/10], Step: [1801/3125], Validation Acc: 62.8
# Epoch: [5/10], Step: [1901/3125], Validation Acc: 62.1
# Epoch: [5/10], Step: [2001/3125], Validation Acc: 65.6
# Epoch: [5/10], Step: [2101/3125], Validation Acc: 64.5
# Epoch: [5/10], Step: [2201/3125], Validation Acc: 65.6
# Epoch: [5/10], Step: [2301/3125], Validation Acc: 64.2
# Epoch: [5/10], Step: [2401/3125], Validation Acc: 63.5
# Epoch: [5/10], Step: [2501/3125], Validation Acc: 63.8
# Epoch: [5/10], Step: [2601/3125], Validation Acc: 63.5
# Epoch: [5/10], Step: [2701/3125], Validation Acc: 65.4
# Epoch: [5/10], Step: [2801/3125], Validation Acc: 64.0
# Epoch: [5/10], Step: [2901/3125], Validation Acc: 63.1
# Epoch: [5/10], Step: [3001/3125], Validation Acc: 63.7
# Epoch: [5/10], Step: [3101/3125], Validation Acc: 63.5
# Epoch: [6/10], Step: [101/3125], Validation Acc: 63.9
# Epoch: [6/10], Step: [201/3125], Validation Acc: 63.0
# Epoch: [6/10], Step: [301/3125], Validation Acc: 64.8
# Epoch: [6/10], Step: [401/3125], Validation Acc: 62.5
# Epoch: [6/10], Step: [501/3125], Validation Acc: 65.2
# Epoch: [6/10], Step: [601/3125], Validation Acc: 65.3
# Epoch: [6/10], Step: [701/3125], Validation Acc: 65.3
# Epoch: [6/10], Step: [801/3125], Validation Acc: 65.9
# Epoch: [6/10], Step: [901/3125], Validation Acc: 64.4
# Epoch: [6/10], Step: [1001/3125], Validation Acc: 65.6
# Epoch: [6/10], Step: [1101/3125], Validation Acc: 64.0
# Epoch: [6/10], Step: [1201/3125], Validation Acc: 64.7
# Epoch: [6/10], Step: [1301/3125], Validation Acc: 64.4
# Epoch: [6/10], Step: [1401/3125], Validation Acc: 62.9
# Epoch: [6/10], Step: [1501/3125], Validation Acc: 63.7
# Epoch: [6/10], Step: [1601/3125], Validation Acc: 64.9
# Epoch: [6/10], Step: [1701/3125], Validation Acc: 64.7
# Epoch: [6/10], Step: [1801/3125], Validation Acc: 64.4
# Epoch: [6/10], Step: [1901/3125], Validation Acc: 66.5
# Epoch: [6/10], Step: [2001/3125], Validation Acc: 64.6
# Epoch: [6/10], Step: [2101/3125], Validation Acc: 64.7
# Epoch: [6/10], Step: [2201/3125], Validation Acc: 66.3
# Epoch: [6/10], Step: [2301/3125], Validation Acc: 65.8
# Epoch: [6/10], Step: [2401/3125], Validation Acc: 61.3
# Epoch: [6/10], Step: [2501/3125], Validation Acc: 63.9
# Epoch: [6/10], Step: [2601/3125], Validation Acc: 63.5
# Epoch: [6/10], Step: [2701/3125], Validation Acc: 64.0
# Epoch: [6/10], Step: [2801/3125], Validation Acc: 63.8
# Epoch: [6/10], Step: [2901/3125], Validation Acc: 66.2
# Epoch: [6/10], Step: [3001/3125], Validation Acc: 66.1
# Epoch: [6/10], Step: [3101/3125], Validation Acc: 64.9
# Epoch: [7/10], Step: [101/3125], Validation Acc: 64.9
# Epoch: [7/10], Step: [201/3125], Validation Acc: 64.4
# Epoch: [7/10], Step: [301/3125], Validation Acc: 62.3
# Epoch: [7/10], Step: [401/3125], Validation Acc: 65.2
# Epoch: [7/10], Step: [501/3125], Validation Acc: 63.9
# Epoch: [7/10], Step: [601/3125], Validation Acc: 64.9
# Epoch: [7/10], Step: [701/3125], Validation Acc: 65.2
# Epoch: [7/10], Step: [801/3125], Validation Acc: 65.0
# Epoch: [7/10], Step: [901/3125], Validation Acc: 64.0
# Epoch: [7/10], Step: [1001/3125], Validation Acc: 65.1
# Epoch: [7/10], Step: [1101/3125], Validation Acc: 64.3
# Epoch: [7/10], Step: [1201/3125], Validation Acc: 64.3
# Epoch: [7/10], Step: [1301/3125], Validation Acc: 64.3
# Epoch: [7/10], Step: [1401/3125], Validation Acc: 65.9
# Epoch: [7/10], Step: [1501/3125], Validation Acc: 64.0
# Epoch: [7/10], Step: [1601/3125], Validation Acc: 65.1
# Epoch: [7/10], Step: [1701/3125], Validation Acc: 65.9
# Epoch: [7/10], Step: [1801/3125], Validation Acc: 64.4
# Epoch: [7/10], Step: [1901/3125], Validation Acc: 66.7
# Epoch: [7/10], Step: [2001/3125], Validation Acc: 65.8
# Epoch: [7/10], Step: [2101/3125], Validation Acc: 66.5
# Epoch: [7/10], Step: [2201/3125], Validation Acc: 65.8
# Epoch: [7/10], Step: [2301/3125], Validation Acc: 64.8
# Epoch: [7/10], Step: [2401/3125], Validation Acc: 63.8
# Epoch: [7/10], Step: [2501/3125], Validation Acc: 65.4
# Epoch: [7/10], Step: [2601/3125], Validation Acc: 66.6
# Epoch: [7/10], Step: [2701/3125], Validation Acc: 66.1
# Epoch: [7/10], Step: [2801/3125], Validation Acc: 66.2
# Epoch: [7/10], Step: [2901/3125], Validation Acc: 64.7
# Epoch: [7/10], Step: [3001/3125], Validation Acc: 66.3
# Epoch: [7/10], Step: [3101/3125], Validation Acc: 66.2
# Epoch: [8/10], Step: [101/3125], Validation Acc: 66.3
# Epoch: [8/10], Step: [201/3125], Validation Acc: 65.1
# Epoch: [8/10], Step: [301/3125], Validation Acc: 65.0
# Epoch: [8/10], Step: [401/3125], Validation Acc: 65.9
# Epoch: [8/10], Step: [501/3125], Validation Acc: 64.9
# Epoch: [8/10], Step: [601/3125], Validation Acc: 64.8
# Epoch: [8/10], Step: [701/3125], Validation Acc: 66.5
# Epoch: [8/10], Step: [801/3125], Validation Acc: 65.8
# Epoch: [8/10], Step: [901/3125], Validation Acc: 65.5
# Epoch: [8/10], Step: [1001/3125], Validation Acc: 65.9
# Epoch: [8/10], Step: [1101/3125], Validation Acc: 65.3
# Epoch: [8/10], Step: [1201/3125], Validation Acc: 64.6
# Epoch: [8/10], Step: [1301/3125], Validation Acc: 66.9
# Epoch: [8/10], Step: [1401/3125], Validation Acc: 65.5
# Epoch: [8/10], Step: [1501/3125], Validation Acc: 66.6
# Epoch: [8/10], Step: [1601/3125], Validation Acc: 66.8
# Epoch: [8/10], Step: [1701/3125], Validation Acc: 65.7
# Epoch: [8/10], Step: [1801/3125], Validation Acc: 64.8
# Epoch: [8/10], Step: [1901/3125], Validation Acc: 65.0
# Epoch: [8/10], Step: [2001/3125], Validation Acc: 64.8
# Epoch: [8/10], Step: [2101/3125], Validation Acc: 66.6
# Epoch: [8/10], Step: [2201/3125], Validation Acc: 66.0
# Epoch: [8/10], Step: [2301/3125], Validation Acc: 65.1
# Epoch: [8/10], Step: [2401/3125], Validation Acc: 65.2
